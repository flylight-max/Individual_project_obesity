# %% [markdown]
# # **Packages**

# %%
import pandas as pd
import ipywidgets as widgets
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno as msno
import itertools

from my_module import *

from statsmodels.stats.proportion import proportions_ztest as pz
from scipy.stats import mannwhitneyu

from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %%
#!pip install missingno

# %% [markdown]
# # **Dataset description**

# %% [markdown]
# The Dataset was dowloaded from kaggle. It belongs to a competition where the goal was to make the best predictive model for "NObeyesdad" (class of weight) using a specific metric as the common reference for all participants. It is made of real and synthetic data. Hence, I wouldn't trust the biological insights taken from there.
# On principle, this doesn't seem that challenging, however, the challenge comes from the missing values as you will see.
# Therefore, before getting any further into information extraction, I had first to impute the missing values and find a way to trust it.
#
# The output variable "NObeyesdad":
# Composed of 7 classes.
# - "Insufficient_Weight";
# - "Normal_Weight";
# - "Overweight_Level_I";
# - "Overweight_Level_II";
# - "Obesity_Type_I";
# - "Obesity_Type_II";
# - "Obesity_Type_III"
#
# Features:
# The features can be divided into 3 groups.
#
# - **Demographic**: Gender, Age, Height, Weight, family_history_with_overweight;
#
# - **Dietary**: FAVC (Frequent High Calorie Food), FCVC (Vegetable Consumption Frequency), NCP (Number of Daily Meals), CAEC (Consumption of Food Between Meals);
#
# - **Lifestyle**: SMOKE (Smoking Habit), CH2O (Daily Water Intake), SCC (Calorie Monitoring), FAF (Physical Activity Frequency), TUE (Technological Device Usage Time), CALC (Alcohol Consumption Frequency), MTRANS (Main Mode of Transportation).
#
# Once the dataset cleaned (mostly imputed the missing values), I could start to extract information from it. The analysis will follow three main questions.
# - Is one of these 3 features subdivisions more prevalent on obesity?
# - Are the factors that influence overweight and obesity different between male and females?
# - We all know that snacking (CAEC) on a long run is not good for our metabolism and health, however, does snacking inevitably leads to obesity? And if not, why?

# %% [markdown]
# # **Obesity dataset exploration**

# %%
train_set_df = pd.read_csv("train.csv")
train_set_df.head()
# Out:
#    ID   Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  \
# 0   1  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no
# 1   2  21.0     NaN    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes
# 2   3   NaN    Male     NaN    77.0  Frequently   no   2.0  3.0   no    no
# 3   4  27.0     NaN     NaN    87.0  Frequently   no   3.0  3.0   no   NaN
# 4   5  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no
#
#    CH2O family_history_with_overweight  FAF  TUE       CAEC  \
# 0   2.0                            yes  0.0  1.0  Sometimes
# 1   3.0                            yes  3.0  NaN  Sometimes
# 2   2.0                            yes  2.0  NaN  Sometimes
# 3   2.0                            NaN  2.0  0.0        NaN
# 4   2.0                             no  0.0  0.0  Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
train_set_df["NObeyesdad"].value_counts()
# Out:
# NObeyesdad
# Overweight_Level_I     290
# Normal_Weight          287
# Insufficient_Weight    272
# Overweight_Level_II    191
# Obesity_Type_I          47
# Obesity_Type_III        12
# Obesity_Type_II         11
# Name: count, dtype: int64

# %%
train_set_df = train_set_df[["ID","Gender","Age","Height","Weight","family_history_with_overweight","FAVC","FCVC","NCP","CAEC","SMOKE","CH2O","SCC","FAF","TUE","CALC","MTRANS","NObeyesdad"]]

# %%
train_set_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1110 non-null   int64
#  1   Gender                          760 non-null    object
#  2   Age                             801 non-null    float64
#  3   Height                          873 non-null    float64
#  4   Weight                          753 non-null    float64
#  5   family_history_with_overweight  990 non-null    object
#  6   FAVC                            609 non-null    object
#  7   FCVC                            1110 non-null   float64
#  8   NCP                             1108 non-null   float64
#  9   CAEC                            790 non-null    object
#  10  SMOKE                           777 non-null    object
#  11  CH2O                            1110 non-null   float64
#  12  SCC                             1110 non-null   object
#  13  FAF                             1097 non-null   float64
#  14  TUE                             895 non-null    float64
#  15  CALC                            1056 non-null   object
#  16  MTRANS                          924 non-null    object
#  17  NObeyesdad                      1110 non-null   object
# dtypes: float64(8), int64(1), object(9)
# memory usage: 156.2+ KB

# %% [markdown]
# Only 3 features are complete (outside the ID). All the others have missing values.

# %%
msno.matrix(train_set_df)
plt.show()

# %% [markdown]
# The category that has the most of missing values is Demographic. Those features won't be helpful to implement the missing values of the other features.

# %%
@widgets.interact
def missing_vals(attribute = list(train_set_df.columns)):
    prop = train_set_df[attribute].isna().sum()/len(train_set_df)
    print(f"Proportion of missing values for the column {attribute}: {prop}")
# Out:
# interactive(children=(Dropdown(description='attribute', options=('ID', 'Gender', 'Age', 'Height', 'Weight', 'f…

# %%
miss_NCP = train_set_df[train_set_df["NCP"].isna()]
miss_NCP
# Out:
#         ID Gender   Age  Height  Weight family_history_with_overweight FAVC  \
# 188    189    NaN  35.0    1.78     NaN                            yes  NaN
# 1009  1010   Male  23.0     NaN    90.0                            yes  yes
#
#           FCVC  NCP       CAEC SMOKE      CH2O SCC  FAF       TUE        CALC  \
# 188   3.000000  NaN         no    no  3.000000  no  3.0  1.000000  Frequently
# 1009  2.067817  NaN  Sometimes   NaN  1.082084  no  0.0  1.922364   Sometimes
#
#                      MTRANS           NObeyesdad
# 188              Automobile       Obesity_Type_I
# 1009  Public_Transportation  Overweight_Level_II

# %%
train_set_df = train_set_df.dropna(subset=["NCP"])

# %%
train_set_df["Gender"].dtype
# Out:
# dtype('O')

# %%
len(train_set_df)
# Out:
# 1108

# %% [markdown]
# ## **Duplicates**

# %%
len(train_set_df["ID"].unique())
# Out:
# 1108

# %%
columns_list = train_set_df.columns
duplicates = train_set_df[train_set_df.duplicated(subset=columns_list[1:], keep=False)]
duplicates
# Out:
#       ID Gender   Age  Height  Weight family_history_with_overweight FAVC  \
# 179  180    NaN  21.0    1.62    70.0                             no  yes
# 763  764    NaN  21.0    1.62    70.0                             no  yes
#
#      FCVC  NCP CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 179   2.0  1.0   no    no   3.0  no  1.0  0.0  Sometimes
# 763   2.0  1.0   no    no   3.0  no  1.0  0.0  Sometimes
#
#                     MTRANS          NObeyesdad
# 179  Public_Transportation  Overweight_Level_I
# 763  Public_Transportation  Overweight_Level_I

# %% [markdown]
# Apart from the ID number, the 2 rows are exactly the same.
# I am removing one of them.

# %%
train_set_df.drop(duplicates.index[0], inplace=True)

# %%
train_set_df.reset_index(drop=True, inplace=True)

# %%
train_set_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    object
#  2   Age                             798 non-null    float64
#  3   Height                          871 non-null    float64
#  4   Weight                          751 non-null    float64
#  5   family_history_with_overweight  987 non-null    object
#  6   FAVC                            607 non-null    object
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    object
#  10  SMOKE                           775 non-null    object
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   object
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   object
#  16  MTRANS                          921 non-null    object
#  17  NObeyesdad                      1107 non-null   object
# dtypes: float64(8), int64(1), object(9)
# memory usage: 155.8+ KB

# %%
missing_values = pd.DataFrame(train_set_df.isna().sum(), columns=["missing values"])
missing_values["cummulative nan"] = missing_values["missing values"].cumsum()
total_missing_vals = missing_values.loc["NObeyesdad", "cummulative nan"]
prop_missing_vals = total_missing_vals/(18*1107)
print(f"Proportion of missing values: {prop_missing_vals}")
# Out:
# Proportion of missing values: 0.1500050185687042

# %% [markdown]
# # **Imputing height and weight with BMI and output variable**

# %%
train_set_df["NObeyesdad"] = train_set_df["NObeyesdad"].astype("category")
weight_cats = train_set_df["NObeyesdad"].cat.categories
order_classes = ["Insufficient_Weight","Normal_Weight","Overweight_Level_I","Overweight_Level_II", "Obesity_Type_I", "Obesity_Type_II","Obesity_Type_III"]
train_set_df["NObeyesdad"] = train_set_df["NObeyesdad"].cat.reorder_categories(order_classes,ordered=True)

# %%
train_set_df["BMI"] = train_set_df["Weight"] / (train_set_df["Height"]**2)

# %% [markdown]
# -           |   Underweight   |   Normal Weight   | Overweight  |  Obese type I   |  Obese type II  |  Obese Type III
# -----------   |   ------------- |  --------------   | ----------  |  ------------   |  -------------  |  --------------
# BMI (kg/m²)   |     < 18.5     |     18.5 - 24.9    | 25 - 29.9   |   30 - 34.9       |   35 - 39.9     |   > 40
#
# Chart found on wikipedia [BMI chart](https://en.wikipedia.org/wiki/Body_mass_index#Categories)

# %%
train_set_df.groupby("NObeyesdad")["BMI"].describe()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\1074112169.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_set_df.groupby("NObeyesdad")["BMI"].describe()
#                      count       mean       std        min        25%  \
# NObeyesdad
# Insufficient_Weight  145.0  17.436453  0.855126  12.998685  17.108967
# Normal_Weight        153.0  22.032574  1.837668  18.496499  20.545694
# Overweight_Level_I   151.0  26.051255  0.635887  24.171508  25.657388
# Overweight_Level_II  109.0  28.231017  0.866691  25.713513  27.673938
# Obesity_Type_I        22.0  31.708290  1.154459  30.119376  30.662768
# Obesity_Type_II        6.0  36.009858  1.313990  35.003199  35.205078
# Obesity_Type_III       8.0  43.266957  2.722505  39.493737  41.913177
#
#                            50%        75%        max
# NObeyesdad
# Insufficient_Weight  17.578125  17.913122  19.082206
# Normal_Weight        22.313278  23.661439  24.840980
# Overweight_Level_I   26.104525  26.446729  28.769607
# Overweight_Level_II  28.184761  28.896224  30.015298
# Obesity_Type_I       31.561958  32.647134  33.742423
# Obesity_Type_II      35.591562  36.097360  38.530612
# Obesity_Type_III     42.411166  44.708373  48.572062

# %%
train_set_df.loc[(train_set_df["BMI"] >= 18.5) & (train_set_df["NObeyesdad"] == "Insufficient_Weight"), "NObeyesdad"] = "Normal_Weight"
train_set_df.loc[(train_set_df["BMI"] < 25) & (train_set_df["NObeyesdad"] == "Overweight_Level_I"), "NObeyesdad"] = "Normal_Weight"
train_set_df.loc[(train_set_df["BMI"] > 29.9) & (train_set_df["NObeyesdad"] == "Overweight_Level_II"),"NObeyesdad"] = "Obesity_Type_I"
train_set_df.loc[(train_set_df["BMI"] <= 39.9) & (train_set_df["NObeyesdad"] == "Obesity_Type_III"),"NObeyesdad"] = "Obesity_Type_II"

# %%
sumStat_BMI = train_set_df.groupby("NObeyesdad")["BMI"].describe()
sumStat_BMI
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\2387443699.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sumStat_BMI = train_set_df.groupby("NObeyesdad")["BMI"].describe()
#                      count       mean       std        min        25%  \
# NObeyesdad
# Insufficient_Weight  141.0  17.397557  0.833713  12.998685  17.099278
# Normal_Weight        163.0  22.046947  1.915496  18.496499  20.264848
# Overweight_Level_I   145.0  26.112421  0.568008  25.064403  25.711662
# Overweight_Level_II  107.0  28.198392  0.840679  25.713513  27.645263
# Obesity_Type_I        24.0  31.563970  1.206684  29.937595  30.533854
# Obesity_Type_II        7.0  36.507555  1.781214  35.003199  35.224971
# Obesity_Type_III       7.0  43.805989  2.436293  41.913063  42.002464
#
#                            50%        75%        max
# NObeyesdad
# Insufficient_Weight  17.572326  17.904117  18.494228
# Normal_Weight        22.313278  23.773811  24.950732
# Overweight_Level_I   26.122490  26.461132  28.769607
# Overweight_Level_II  28.179596  28.838741  29.859733
# Obesity_Type_I       31.190641  32.635279  33.742423
# Obesity_Type_II      35.918367  37.343819  39.493737
# Obesity_Type_III     42.730620  44.710625  48.572062

# %%
sns.boxplot(x="NObeyesdad",y="BMI",data=train_set_df)
plt.xticks(rotation=90)
plt.show()

# %%
#Height
miss_Height = train_set_df[train_set_df["Height"].isna()].copy(deep=False)
miss_Height.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 236 entries, 2 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              236 non-null    int64
#  1   Gender                          162 non-null    object
#  2   Age                             167 non-null    float64
#  3   Height                          0 non-null      float64
#  4   Weight                          157 non-null    float64
#  5   family_history_with_overweight  205 non-null    object
#  6   FAVC                            130 non-null    object
#  7   FCVC                            236 non-null    float64
#  8   NCP                             236 non-null    float64
#  9   CAEC                            180 non-null    object
#  10  SMOKE                           161 non-null    object
#  11  CH2O                            236 non-null    float64
#  12  SCC                             236 non-null    object
#  13  FAF                             236 non-null    float64
#  14  TUE                             193 non-null    float64
#  15  CALC                            225 non-null    object
#  16  MTRANS                          195 non-null    object
#  17  NObeyesdad                      236 non-null    category
#  18  BMI                             0 non-null      float64
# dtypes: category(1), float64(9), int64(1), object(8)
# memory usage: 35.6+ KB

# %%
Weight_miss_Height = miss_Height[~(miss_Height["Weight"].isna())].copy(deep=False)
Weight_miss_Height.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 2 to 1103
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              157 non-null    int64
#  1   Gender                          107 non-null    object
#  2   Age                             111 non-null    float64
#  3   Height                          0 non-null      float64
#  4   Weight                          157 non-null    float64
#  5   family_history_with_overweight  137 non-null    object
#  6   FAVC                            84 non-null     object
#  7   FCVC                            157 non-null    float64
#  8   NCP                             157 non-null    float64
#  9   CAEC                            119 non-null    object
#  10  SMOKE                           105 non-null    object
#  11  CH2O                            157 non-null    float64
#  12  SCC                             157 non-null    object
#  13  FAF                             157 non-null    float64
#  14  TUE                             130 non-null    float64
#  15  CALC                            152 non-null    object
#  16  MTRANS                          132 non-null    object
#  17  NObeyesdad                      157 non-null    category
#  18  BMI                             0 non-null      float64
# dtypes: category(1), float64(9), int64(1), object(8)
# memory usage: 23.8+ KB

# %%
def replace_in_df(df,clasW):
    df.loc[df["NObeyesdad"] == clasW,"BMI"] = sumStat_BMI.loc[clasW,"50%"]

replace_in_df(Weight_miss_Height,"Insufficient_Weight")
replace_in_df(Weight_miss_Height,"Normal_Weight")
replace_in_df(Weight_miss_Height,"Overweight_Level_I")
replace_in_df(Weight_miss_Height,"Overweight_Level_II")
replace_in_df(Weight_miss_Height,"Obesity_Type_I")
replace_in_df(Weight_miss_Height,"Obesity_Type_II")
replace_in_df(Weight_miss_Height,"Obesity_Type_III")

# %%
Weight_miss_Height.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 2 to 1103
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              157 non-null    int64
#  1   Gender                          107 non-null    object
#  2   Age                             111 non-null    float64
#  3   Height                          0 non-null      float64
#  4   Weight                          157 non-null    float64
#  5   family_history_with_overweight  137 non-null    object
#  6   FAVC                            84 non-null     object
#  7   FCVC                            157 non-null    float64
#  8   NCP                             157 non-null    float64
#  9   CAEC                            119 non-null    object
#  10  SMOKE                           105 non-null    object
#  11  CH2O                            157 non-null    float64
#  12  SCC                             157 non-null    object
#  13  FAF                             157 non-null    float64
#  14  TUE                             130 non-null    float64
#  15  CALC                            152 non-null    object
#  16  MTRANS                          132 non-null    object
#  17  NObeyesdad                      157 non-null    category
#  18  BMI                             157 non-null    float64
# dtypes: category(1), float64(9), int64(1), object(8)
# memory usage: 23.8+ KB

# %%
#NOT GOOD! NEED TO BE CHANGED!!!
for cat in weight_cats:
    Weight_miss_Height.loc[Weight_miss_Height["NObeyesdad"] == cat,"Height"] = np.sqrt(\
        Weight_miss_Height.loc[Weight_miss_Height["NObeyesdad"] == cat,"Weight"]\
            /Weight_miss_Height.loc[Weight_miss_Height["NObeyesdad"] == cat, "BMI"])

Weight_miss_Height.head()
# Out:
#     ID  Gender   Age    Height  Weight family_history_with_overweight FAVC  \
# 2    3    Male   NaN  1.857649    77.0                            yes   no
# 3    4     NaN  27.0  1.824956    87.0                            NaN   no
# 14  15    Male   NaN  1.639812    60.0                            yes  NaN
# 15  16     NaN   NaN  1.719849    66.0                            yes   no
# 18  19  Female   NaN  1.705845    82.0                            yes  NaN
#
#     FCVC  NCP        CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 2    2.0  3.0   Sometimes    no   2.0   no  2.0  NaN  Frequently
# 3    3.0  3.0         NaN   NaN   2.0   no  2.0  0.0  Frequently
# 14   3.0  1.0   Sometimes   NaN   1.0   no  1.0  1.0   Sometimes
# 15   3.0  3.0      Always   NaN   2.0  yes  2.0  1.0   Sometimes
# 18   3.0  4.0  Frequently   yes   1.0   no  0.0  NaN          no
#
#                    MTRANS           NObeyesdad        BMI
# 2   Public_Transportation        Normal_Weight  22.313278
# 3                 Walking   Overweight_Level_I  26.122490
# 14  Public_Transportation        Normal_Weight  22.313278
# 15  Public_Transportation        Normal_Weight  22.313278
# 18             Automobile  Overweight_Level_II  28.179596

# %%
train_set_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    object
#  2   Age                             798 non-null    float64
#  3   Height                          871 non-null    float64
#  4   Weight                          751 non-null    float64
#  5   family_history_with_overweight  987 non-null    object
#  6   FAVC                            607 non-null    object
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    object
#  10  SMOKE                           775 non-null    object
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   object
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   object
#  16  MTRANS                          921 non-null    object
#  17  NObeyesdad                      1107 non-null   category
#  18  BMI                             594 non-null    float64
# dtypes: category(1), float64(9), int64(1), object(8)
# memory usage: 157.2+ KB

# %%
train_set_df.loc[train_set_df["ID"] == 2].values
# Out:
# array([[2, nan, 21.0, 1.52, 56.0, 'yes', 'no', 3.0, 3.0, 'Sometimes',
#         'yes', 3.0, 'yes', 3.0, nan, 'Sometimes',
#         'Public_Transportation', 'Normal_Weight', 24.238227146814403]],
#       dtype=object)

# %%
for id in Weight_miss_Height["ID"]:
    train_set_df.loc[train_set_df["ID"] == id,:] = Weight_miss_Height.loc[Weight_miss_Height["ID"] == id,:]

# %%
train_set_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    object
#  2   Age                             798 non-null    float64
#  3   Height                          1028 non-null   float64
#  4   Weight                          751 non-null    float64
#  5   family_history_with_overweight  987 non-null    object
#  6   FAVC                            607 non-null    object
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    object
#  10  SMOKE                           775 non-null    object
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   object
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   object
#  16  MTRANS                          921 non-null    object
#  17  NObeyesdad                      1107 non-null   category
#  18  BMI                             751 non-null    float64
# dtypes: category(1), float64(9), int64(1), object(8)
# memory usage: 157.2+ KB

# %%
missing_weight = train_set_df[train_set_df["Weight"].isna()].copy()

# %%
missing_weight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 356 entries, 7 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              356 non-null    int64
#  1   Gender                          253 non-null    object
#  2   Age                             260 non-null    float64
#  3   Height                          277 non-null    float64
#  4   Weight                          0 non-null      float64
#  5   family_history_with_overweight  311 non-null    object
#  6   FAVC                            198 non-null    object
#  7   FCVC                            356 non-null    float64
#  8   NCP                             356 non-null    float64
#  9   CAEC                            245 non-null    object
#  10  SMOKE                           257 non-null    object
#  11  CH2O                            356 non-null    float64
#  12  SCC                             356 non-null    object
#  13  FAF                             351 non-null    float64
#  14  TUE                             283 non-null    float64
#  15  CALC                            341 non-null    object
#  16  MTRANS                          288 non-null    object
#  17  NObeyesdad                      356 non-null    category
#  18  BMI                             0 non-null      float64
# dtypes: category(1), float64(9), int64(1), object(8)
# memory usage: 53.5+ KB

# %%
height_miss_weight = missing_weight[~(missing_weight["Height"].isna())].copy()

replace_in_df(height_miss_weight,"Insufficient_Weight")
replace_in_df(height_miss_weight,"Normal_Weight")
replace_in_df(height_miss_weight,"Overweight_Level_I")
replace_in_df(height_miss_weight,"Overweight_Level_II")
replace_in_df(height_miss_weight,"Obesity_Type_I")
replace_in_df(height_miss_weight,"Obesity_Type_II")
replace_in_df(height_miss_weight,"Obesity_Type_III")

# %%
for cat in weight_cats:
    height_miss_weight.loc[height_miss_weight["NObeyesdad"] == cat,"Weight"] = \
    height_miss_weight.loc[height_miss_weight["NObeyesdad"] == cat,"Height"]**2 *\
    height_miss_weight.loc[height_miss_weight["NObeyesdad"] == cat, "BMI"]

height_miss_weight.head()
# Out:
#     ID  Gender   Age  Height     Weight family_history_with_overweight FAVC  \
# 7    8     NaN  22.0    1.64  60.013794                             no   no
# 30  31    Male  29.0    1.77  81.839148                             no  yes
# 32  33     NaN   NaN    1.77  69.905270                             no   no
# 38  39    Male  23.0    1.65  60.747901                            yes  yes
# 39  40  Female  21.0    1.75  86.300014                            NaN  yes
#
#     FCVC  NCP       CAEC SMOKE  CH2O SCC  FAF  TUE       CALC  \
# 7    2.0  3.0        NaN    no   2.0  no  3.0  NaN  Sometimes
# 30   1.0  4.0        NaN    no   3.0  no  0.0  1.0         no
# 32   2.0  3.0  Sometimes    no   3.0  no  1.0  1.0  Sometimes
# 38   2.0  3.0  Sometimes    no   2.0  no  1.0  NaN  Sometimes
# 39   2.0  3.0  Sometimes   NaN   3.0  no  3.0  0.0  Sometimes
#
#                    MTRANS           NObeyesdad        BMI
# 7   Public_Transportation        Normal_Weight  22.313278
# 30              Motorbike   Overweight_Level_I  26.122490
# 32                Walking        Normal_Weight  22.313278
# 38  Public_Transportation        Normal_Weight  22.313278
# 39  Public_Transportation  Overweight_Level_II  28.179596

# %%
for id in height_miss_weight["ID"]:
    train_set_df.loc[train_set_df["ID"] == id,:] = \
        height_miss_weight.loc[height_miss_weight["ID"] == id,:]

# %%
train_set_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    object
#  2   Age                             798 non-null    float64
#  3   Height                          1028 non-null   float64
#  4   Weight                          1028 non-null   float64
#  5   family_history_with_overweight  987 non-null    object
#  6   FAVC                            607 non-null    object
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    object
#  10  SMOKE                           775 non-null    object
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   object
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   object
#  16  MTRANS                          921 non-null    object
#  17  NObeyesdad                      1107 non-null   category
#  18  BMI                             1028 non-null   float64
# dtypes: category(1), float64(9), int64(1), object(8)
# memory usage: 157.2+ KB

# %%
train_set_df.groupby("NObeyesdad")["BMI"].describe()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\1074112169.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_set_df.groupby("NObeyesdad")["BMI"].describe()
#                      count       mean       std        min        25%  \
# NObeyesdad
# Insufficient_Weight  247.0  17.472559  0.634890  12.998685  17.508263
# Normal_Weight        280.0  22.158236  1.465529  18.496499  22.021760
# Overweight_Level_I   259.0  26.116853  0.424381  25.064403  26.066021
# Overweight_Level_II  177.0  28.190959  0.652484  25.713513  28.035577
# Obesity_Type_I        45.0  31.389750  0.892532  29.937595  31.141869
# Obesity_Type_II        9.0  36.376624  1.564303  35.003199  35.264757
# Obesity_Type_III      11.0  43.414946  1.963587  41.913063  42.411166
#
#                            50%        75%        max
# NObeyesdad
# Insufficient_Weight  17.572326  17.625270  18.494228
# Normal_Weight        22.313278  22.507444  24.950732
# Overweight_Level_I   26.122490  26.214171  28.769607
# Overweight_Level_II  28.179596  28.363642  29.859733
# Obesity_Type_I       31.190641  31.239414  33.742423
# Obesity_Type_II      35.918367  36.157025  39.493737
# Obesity_Type_III     42.730620  43.718370  48.572062

# %% [markdown]
# -           |   Underweight   |   Normal Weight   | Overweight  |  Obese type I   |  Obese type II  |  Obese Type III
# -----------   |   ------------- |  --------------   | ----------  |  ------------   |  -------------  |  --------------
# BMI (kg/m²)   |     < 18.5     |     18.5 - 24.9    | 25 - 29.9   |   30 - 34.9       |   35 - 39.9     |   > 40

# %% [markdown]
# # **From object to numbers**

# %% [markdown]
# ## **binomial features**

# %%
for col in train_set_df.columns:
    if train_set_df[col].dtype == "O":
        train_set_df[col] = train_set_df[col].astype("category")

@widgets.interact
def binom_multinom(attribute=list(train_set_df.select_dtypes("category").columns)):
    n_cat = len(train_set_df[attribute].cat.categories)
    categories = train_set_df[attribute].cat.categories
    print(f"the feature {attribute} has {n_cat} categories. \nThey are: \n{categories}")
# Out:
# interactive(children=(Dropdown(description='attribute', options=('Gender', 'family_history_with_overweight', '…

# %% [markdown]
# Most of the categorical features are binomiale.

# %%
def binom_bool(df,col,cat_1):
    new = np.where(df[col] == cat_1,0,np.where(pd.isna(df[col]),np.nan,1))
    return new

# %%
train_set_df["Gender"].cat.categories[0]
# Out:
# 'Female'

# %%
counts_gender = train_set_df["Gender"].value_counts(dropna=False)
counts_gender.index[2]
# Out:
# nan

# %%
data_num = train_set_df.copy()

list_binom_bool_dict = []
list_binom_cols = []
for col in data_num.select_dtypes("category").columns:
    n_cat = len(data_num[col].cat.categories)
    dict_col = {}
    if n_cat == 2:
        cats = data_num[col].cat.categories
        cat_1 = cats[0]
        data_num[col] = binom_bool(data_num,col,cat_1)
        dict_col[cat_1] = 0
        dict_col[cats[1]] = 1
        list_binom_bool_dict.append(dict_col)
        list_binom_cols.append(col)
    
print(data_num["Gender"].value_counts(dropna=False))
print(train_set_df["Gender"].value_counts(dropna=False))
print(list_binom_cols)
print(list_binom_bool_dict)
# Out:
# Gender
# 1.0    385
# 0.0    374
# NaN    348
# Name: count, dtype: int64
# Gender
# Male      385
# Female    374
# NaN       348
# Name: count, dtype: int64
# ['Gender', 'family_history_with_overweight', 'FAVC', 'SMOKE', 'SCC']
# [{'Female': 0, 'Male': 1}, {'no': 0, 'yes': 1}, {'no': 0, 'yes': 1}, {'no': 0, 'yes': 1}, {'no': 0, 'yes': 1}]

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    float64
#  2   Age                             798 non-null    float64
#  3   Height                          1028 non-null   float64
#  4   Weight                          1028 non-null   float64
#  5   family_history_with_overweight  987 non-null    float64
#  6   FAVC                            607 non-null    float64
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    category
#  10  SMOKE                           775 non-null    float64
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   float64
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   category
#  16  MTRANS                          921 non-null    category
#  17  NObeyesdad                      1107 non-null   category
#  18  BMI                             1028 non-null   float64
# dtypes: category(4), float64(14), int64(1)
# memory usage: 135.1 KB

# %% [markdown]
# To impute the missing values, I will exclude the last columns "NObeyesdad". I should not include the dependent variable.

# %%
y = data_num[["NObeyesdad"]].copy()

# %% [markdown]
# ## **Multinomial features**

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    float64
#  2   Age                             798 non-null    float64
#  3   Height                          1028 non-null   float64
#  4   Weight                          1028 non-null   float64
#  5   family_history_with_overweight  987 non-null    float64
#  6   FAVC                            607 non-null    float64
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    category
#  10  SMOKE                           775 non-null    float64
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   float64
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   category
#  16  MTRANS                          921 non-null    category
#  17  NObeyesdad                      1107 non-null   category
#  18  BMI                             1028 non-null   float64
# dtypes: category(4), float64(14), int64(1)
# memory usage: 135.1 KB

# %%
@widgets.interact
def binom_multinom(attribute=list(data_num.select_dtypes("category").columns)):
    n_cat = len(data_num[attribute].cat.categories)
    categories = data_num[attribute].cat.categories
    print(f"the feature {attribute} has {n_cat} categories. \nThey are: \n{categories}")
# Out:
# interactive(children=(Dropdown(description='attribute', options=('CAEC', 'CALC', 'MTRANS', 'NObeyesdad'), valu…

# %%
data_num["CALC"] = data_num["CALC"].cat.reorder_categories(new_categories=["no","Sometimes","Frequently"], ordered=True)
data_num["CAEC"] = data_num["CAEC"].cat.reorder_categories(new_categories=["no","Sometimes","Frequently","Always"], ordered=True)

# %%
@widgets.interact
def binom_multinom(attribute=list(data_num.select_dtypes("category").columns)):
    n_cat = len(data_num[attribute].cat.categories)
    categories = data_num[attribute].cat.categories
    print(f"the feature {attribute} has {n_cat} categories. \nThey are: \n{categories}")
# Out:
# interactive(children=(Dropdown(description='attribute', options=('CAEC', 'CALC', 'MTRANS', 'NObeyesdad'), valu…

# %%
Encod_CALC = my_labelEncoder()
Encod_CALC.fit(data_num,"CALC")
dict_CALC = Encod_CALC.dict_cat
data_num["CALC_num"] = Encod_CALC.transform(data_num,"CALC")
print(data_num["CALC_num"].value_counts(dropna=False))
print(dict_CALC)
# Out:
# CALC_num
# 1       632
# 0       363
# 2        58
# <NA>     54
# Name: count, dtype: Int64
# {'no': 0, 'Sometimes': 1, 'Frequently': 2}

# %%
Encod_CAEC = my_labelEncoder()
Encod_CAEC.fit(data_num,"CAEC")
dict_CAEC = Encod_CAEC.dict_cat
data_num["CAEC_num"] = Encod_CAEC.transform(data_num,"CAEC")
print(dict_CAEC)
# Out:
# {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}

# %%
Encod_MTRANS = my_labelEncoder()
Encod_MTRANS.fit(data_num,"MTRANS")
dict_MTRANS = Encod_MTRANS.dict_cat
data_num["MTRANS_num"] = Encod_MTRANS.transform(data_num,"MTRANS")

# %%
Encod_y = my_labelEncoder()
Encod_y.fit(data_num,"NObeyesdad")
dict_y = Encod_y.dict_cat
data_num["NObeyesdad_num"] = Encod_y.transform(data_num,"NObeyesdad")
print(dict_y)
# Out:
# {'Insufficient_Weight': 0, 'Normal_Weight': 1, 'Overweight_Level_I': 2, 'Overweight_Level_II': 3, 'Obesity_Type_I': 4, 'Obesity_Type_II': 5, 'Obesity_Type_III': 6}

# %%
data_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    float64
#  2   Age                             798 non-null    float64
#  3   Height                          1028 non-null   float64
#  4   Weight                          1028 non-null   float64
#  5   family_history_with_overweight  987 non-null    float64
#  6   FAVC                            607 non-null    float64
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    category
#  10  SMOKE                           775 non-null    float64
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   float64
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   category
#  16  MTRANS                          921 non-null    category
#  17  NObeyesdad                      1107 non-null   category
#  18  BMI                             1028 non-null   float64
#  19  CALC_num                        1053 non-null   Int64
#  20  CAEC_num                        787 non-null    Int64
#  21  MTRANS_num                      921 non-null    Int64
#  22  NObeyesdad_num                  1107 non-null   Int64
# dtypes: Int64(4), category(4), float64(14), int64(1)
# memory usage: 174.0 KB

# %%
dataNum_miss = data_num.copy()
dataNum_miss.drop(["ID","CALC","CAEC","MTRANS","NObeyesdad"], axis=1, inplace=True)

# %% [markdown]
# # **Imputing missing values with KNNImputer**

# %%
knnImput = KNNImputer(n_neighbors=5)
Data_num_noMiss = knnImput.fit_transform(dataNum_miss)
Data_num_noMiss = pd.DataFrame(Data_num_noMiss, columns=dataNum_miss.columns)

# %%
Data_num_noMiss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   float64
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   float64
#  5   FAVC                            1107 non-null   float64
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   float64
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   float64
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC_num                        1107 non-null   float64
#  15  CAEC_num                        1107 non-null   float64
#  16  MTRANS_num                      1107 non-null   float64
#  17  NObeyesdad_num                  1107 non-null   float64
# dtypes: float64(18)
# memory usage: 155.8 KB

# %% [markdown]
# 45% of FAVC (Frequent High Caloric Food) has no value. Furthermore, it's only a yes/no answer. I believe therefore that this column won't be informative.

# %% [markdown]
# ## **Exemple of imputed feature: Age**

# %%
train_set_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              1107 non-null   int64
#  1   Gender                          759 non-null    category
#  2   Age                             798 non-null    float64
#  3   Height                          1028 non-null   float64
#  4   Weight                          1028 non-null   float64
#  5   family_history_with_overweight  987 non-null    category
#  6   FAVC                            607 non-null    category
#  7   FCVC                            1107 non-null   float64
#  8   NCP                             1107 non-null   float64
#  9   CAEC                            787 non-null    category
#  10  SMOKE                           775 non-null    category
#  11  CH2O                            1107 non-null   float64
#  12  SCC                             1107 non-null   category
#  13  FAF                             1094 non-null   float64
#  14  TUE                             892 non-null    float64
#  15  CALC                            1053 non-null   category
#  16  MTRANS                          921 non-null    category
#  17  NObeyesdad                      1107 non-null   category
#  18  BMI                             1028 non-null   float64
# dtypes: category(9), float64(9), int64(1)
# memory usage: 97.8 KB

# %%
sns.histplot(train_set_df["Age"], bins=20, color="blue")    
sns.histplot(Data_num_noMiss["Age"], bins=20, color="red", alpha=0.5)
plt.show()

# %% [markdown]
# We can see with this example that the model respected the distribution pattern.

# %% [markdown]
# ## **Reversing from numbers to categories**

# %% [markdown]
# ### **Multinomiales**

# %%
Encod_MTRANS.dict_cat
# Out:
# {'Automobile': 0,
#  'Bike': 1,
#  'Motorbike': 2,
#  'Public_Transportation': 3,
#  'Walking': 4}

# %%
X = Data_num_noMiss.copy()
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   float64
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   float64
#  5   FAVC                            1107 non-null   float64
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   float64
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   float64
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC_num                        1107 non-null   float64
#  15  CAEC_num                        1107 non-null   float64
#  16  MTRANS_num                      1107 non-null   float64
#  17  NObeyesdad_num                  1107 non-null   float64
# dtypes: float64(18)
# memory usage: 155.8 KB

# %%
categorical_cols = ["CALC_num","CAEC_num","MTRANS_num","Gender",\
                    "family_history_with_overweight","FAVC","SMOKE","SCC", "NObeyesdad_num"]
for col in categorical_cols:
    X[col] = X[col].astype("int32")

# %%
for col in categorical_cols:
    Data_num_noMiss[col] = Data_num_noMiss[col].astype("int32")

# %%
Data_num_noMiss["MTRANS_num"].value_counts(dropna=False)
# Out:
# MTRANS_num
# 3    754
# 0    216
# 2     57
# 4     47
# 1     33
# Name: count, dtype: int64

# %%
Data_num_noMiss["CALC"] = Encod_CALC.reverse_transform(Data_num_noMiss,"CALC_num")
Data_num_noMiss["CAEC"] = Encod_CAEC.reverse_transform(Data_num_noMiss,"CAEC_num")
Data_num_noMiss["MTRANS"] = Encod_MTRANS.reverse_transform(Data_num_noMiss,"MTRANS_num")
Data_num_noMiss["NObeyesdad"] = Encod_y.reverse_transform(Data_num_noMiss,"NObeyesdad_num")

# %%
Data_num_noMiss.drop(["CALC_num","CAEC_num","MTRANS_num", "NObeyesdad_num"], axis=1, inplace=True)

# %%
Data_num_noMiss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   int32
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   int32
#  5   FAVC                            1107 non-null   int32
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   int32
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   int32
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC                            1107 non-null   object
#  15  CAEC                            1107 non-null   object
#  16  MTRANS                          1107 non-null   object
#  17  NObeyesdad                      1107 non-null   object
# dtypes: float64(9), int32(5), object(4)
# memory usage: 134.2+ KB

# %% [markdown]
# ## **Binomiale features**

# %%
@widgets.interact
def binom_multinom(attribute=list(train_set_df.select_dtypes("category").columns)):
    n_cat = len(train_set_df[attribute].cat.categories)
    categories = train_set_df[attribute].cat.categories
    print(f"the feature {attribute} has {n_cat} categories. \nThey are: \n{categories}")
# Out:
# interactive(children=(Dropdown(description='attribute', options=('Gender', 'family_history_with_overweight', '…

# %%
print(list_binom_bool_dict)
print(list_binom_cols)
# Out:
# [{'Female': 0, 'Male': 1}, {'no': 0, 'yes': 1}, {'no': 0, 'yes': 1}, {'no': 0, 'yes': 1}, {'no': 0, 'yes': 1}]
# ['Gender', 'family_history_with_overweight', 'FAVC', 'SMOKE', 'SCC']

# %%
list_bool_binom_dict = []
for dicti in list_binom_bool_dict:
    dicti_bool = {v:k for k,v in dicti.items()}
    list_bool_binom_dict.append(dicti_bool)

# %%
for col,dicti in zip(list_binom_cols,list_bool_binom_dict):
    Data_num_noMiss[col] = Data_num_noMiss[col].map(dicti)

# %%
print(Data_num_noMiss.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   object
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   object
#  5   FAVC                            1107 non-null   object
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   object
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   object
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC                            1107 non-null   object
#  15  CAEC                            1107 non-null   object
#  16  MTRANS                          1107 non-null   object
#  17  NObeyesdad                      1107 non-null   object
# dtypes: float64(9), object(9)
# memory usage: 155.8+ KB
# None

# %%
print(Data_num_noMiss.iloc[5])
print(train_set_df.iloc[5])
# Out:
# Gender                                     Male
# Age                                   20.226623
# Height                                     1.62
# Weight                                     53.0
# family_history_with_overweight               no
# FAVC                                        yes
# FCVC                                        2.0
# NCP                                         3.0
# SMOKE                                        no
# CH2O                                        2.0
# SCC                                          no
# FAF                                         0.0
# TUE                                    1.388935
# BMI                                   20.195092
# CALC                                  Sometimes
# CAEC                                  Sometimes
# MTRANS                               Automobile
# NObeyesdad                        Normal_Weight
# Name: 5, dtype: object
# ID                                            6
# Gender                                     Male
# Age                                         NaN
# Height                                     1.62
# Weight                                     53.0
# family_history_with_overweight               no
# FAVC                                        yes
# FCVC                                        2.0
# NCP                                         3.0
# CAEC                                  Sometimes
# SMOKE                                        no
# CH2O                                        2.0
# SCC                                          no
# FAF                                         0.0
# TUE                                         NaN
# CALC                                  Sometimes
# MTRANS                               Automobile
# NObeyesdad                        Normal_Weight
# BMI                                   20.195092
# Name: 5, dtype: object

# %% [markdown]
# # **EDA**
# Now I have imputed the missing values, I can start exploring the dataset to look for insights.
# since there are 14 columns and 7 classes, a manual exploration would fastidious.
# I am therefore using MLs to get a first glance of the data.

# %%
new_obesity = Data_num_noMiss.copy()

# %%
for col in new_obesity.columns:
    if new_obesity[col].dtype == "O":
        new_obesity[col] = new_obesity[col].astype("category")

# %%
print(y.value_counts())
order_classes = ["Insufficient_Weight","Normal_Weight","Overweight_Level_I","Overweight_Level_II","Obesity_Type_I","Obesity_Type_II","Obesity_Type_III"]
y["NObeyesdad"] = y["NObeyesdad"].cat.reorder_categories(new_categories=order_classes, ordered=True)
new_obesity["NObeyesdad"] = new_obesity["NObeyesdad"].cat.reorder_categories(new_categories=order_classes, ordered=True)

classes = y["NObeyesdad"].cat.categories
classes
# Out:
# NObeyesdad
# Normal_Weight          297
# Overweight_Level_I     283
# Insufficient_Weight    268
# Overweight_Level_II    188
# Obesity_Type_I          48
# Obesity_Type_II         12
# Obesity_Type_III        11
# Name: count, dtype: int64
# Index(['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I',
#        'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II',
#        'Obesity_Type_III'],
#       dtype='object')

# %% [markdown]
# Sadly, the Obesity classes are too few to be useable. We will need more data for these classes if we want to draw conclusions.

# %%
new_obesity.groupby("NObeyesdad")["BMI"].describe()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\3356139958.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   new_obesity.groupby("NObeyesdad")["BMI"].describe()
#                      count       mean       std        min        25%  \
# NObeyesdad
# Insufficient_Weight  268.0  17.461022  0.639020  12.998685  17.461211
# Normal_Weight        297.0  22.147666  1.444763  18.496499  21.875000
# Overweight_Level_I   283.0  26.111931  0.428114  25.064403  26.012058
# Overweight_Level_II  188.0  28.172397  0.647464  25.713513  27.961276
# Obesity_Type_I        48.0  31.290285  0.950301  29.373923  30.831742
# Obesity_Type_II       12.0  35.446269  2.489462  29.433951  35.139689
# Obesity_Type_III      11.0  43.414946  1.963587  41.913063  42.411166
#
#                            50%        75%        max
# NObeyesdad
# Insufficient_Weight  17.572326  17.622395  19.167229
# Normal_Weight        22.313278  22.600263  24.950732
# Overweight_Level_I   26.122490  26.222086  28.769607
# Overweight_Level_II  28.179596  28.347218  29.859733
# Obesity_Type_I       31.190641  31.202835  33.742423
# Obesity_Type_II      35.591562  35.978032  39.493737
# Obesity_Type_III     42.730620  43.718370  48.572062

# %% [markdown]
# -           |   Underweight   |   Normal Weight   | Overweight  |  Obese type I   |  Obese type II  |  Obese Type III
# -----------   |   ------------- |  --------------   | ----------  |  ------------   |  -------------  |  --------------
# BMI (kg/m²)   |     < 18.5     |     18.5 - 24.9    | 25 - 29.9   |   30 - 34.9       |   35 - 39.9     |   > 40

# %% [markdown]
# The max imputed BMI is a bit high for *Insufficient_Weight* but it's not too bad. Only for Obesity Type II the minimum value is quite low and belongs to overweight. However, the number of this class is also very low.

# %% [markdown]
# ## **1) From Demographic, dietary and lifestyle, which one is more prevalent to determine the obesity?**

# %% [markdown]
# Features:
# The features can be divided into 3 groups.
#
# - **Demographic**: Gender, Age, Height, Weight, family_history_with_overweight;
#
# - **Dietary**: FAVC (Frequent High Calorie Food), FCVC (Vegetable Consumption Frequency), NCP (Number of Daily Meals), CAEC (Consumption of Food Between Meals);
#
# - **Lifestyle**: SMOKE (Smoking Habit), CH2O (Daily Water Intake), SCC (Calorie Monitoring), FAF (Physical Activity Frequency), TUE (Technological Device Usage Time), CALC (Alcohol Consumption Frequency), MTRANS (Main Mode of Transportation).
#
# One would think the Dietary would be more prevalent, however, not only this category has at the begining the least number of features (4), but I am removing one of them FAVC since it has too many null values (45%) to be interpretable and the imputed values trusted.
# Hence, would the 3 remaining features be the most influencial?
#
# Note that among the Demographic subgroup is the feature "Weight". Together with "Height", they are sufficient to determine the weight class. Hence, they are important to keep to impute the missing values.
# However, for the EDA, "Weight" has a too heavy influence (even without the "Height"). Hence, I am removing it in addition to "FAVC".

# %%
new_obesity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   category
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   category
#  5   FAVC                            1107 non-null   category
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   category
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   category
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC                            1107 non-null   category
#  15  CAEC                            1107 non-null   category
#  16  MTRANS                          1107 non-null   category
#  17  NObeyesdad                      1107 non-null   category
# dtypes: category(9), float64(9)
# memory usage: 89.2 KB

# %% [markdown]
# Since here the goal is not to build a predictive model, but to class the features by importance, I am going to use the entire dataset and apply a simple LogisticRegression model for multiclasses.

# %%
y.shape
# Out:
# (1107, 1)

# %%
y_resh = y.values.reshape(-1)
y_resh.shape
# Out:
# (1107,)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   int32
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   int32
#  5   FAVC                            1107 non-null   int32
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   int32
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   int32
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC_num                        1107 non-null   int32
#  15  CAEC_num                        1107 non-null   int32
#  16  MTRANS_num                      1107 non-null   int32
#  17  NObeyesdad_num                  1107 non-null   int32
# dtypes: float64(9), int32(9)
# memory usage: 116.9 KB

# %%
X_mod = X.drop(["FAVC","NObeyesdad_num","Weight","BMI"], axis=1)
stScale = StandardScaler()
X_scale = stScale.fit_transform(X_mod)

# %% [markdown]
# ### **Feature importance with logistic regression**

# %%
logReg = LogisticRegression(max_iter=1000)

logReg.fit(X_scale,y_resh)
# Out:
# LogisticRegression(max_iter=1000)

# %%
feature_coefs = logReg.coef_
feature_coefs.shape
# Out:
# (7, 14)

# %%
df_coefs = pd.DataFrame(feature_coefs, columns=X_mod.columns, index=classes)

# %%
def most_import_negFeature(df_coefs, weight_class):
    sorted_coefs = df_coefs.loc[weight_class].sort_values()
    return sorted_coefs[:3]

def most_import_posFeature(df_coefs, weight_class):
    sorted_coefs = df_coefs.loc[weight_class].sort_values(ascending=False)
    return sorted_coefs[:3]

# %%
@widgets.interact
def most_important_negFeature(weight_class = classes):
    print(most_import_negFeature(df_coefs, weight_class))
# Out:
# interactive(children=(Dropdown(description='weight_class', options=('Insufficient_Weight', 'Normal_Weight', 'O…

# %%
@widgets.interact
def most_important_posFeature(weight_class = classes):
    print(most_import_posFeature(df_coefs, weight_class))
# Out:
# interactive(children=(Dropdown(description='weight_class', options=('Insufficient_Weight', 'Normal_Weight', 'O…

# %% [markdown]
# **Influence of the 3 subgroups (Demographic, diet, life style) on the weight classes.**
# . *Insufficient weight*: With a coef = -1.84, "Age" (belongs to **Demographic**) has the most influence (negative) on this class. Comes second with a coef = -0.79 "family_history_with_overweight" (also belongs to **Demographic**). The *Insufficient_Weight* class are on average 1.8 more likely to be younger and 0.79 less likely to have a family history of overweight.
#
# . *Normal weight*: Here none of the features come out with a high coeficient. The highest would be snacking (CAEC) closely followed by "family_history_with_overweight". However, among the first 3 we have 2 features that belong to **Demographic**.
#
# . *Overweight Level I*: Although the values here again are not so high, both **Demographic** and **Dietary** would be the most influencial. It is important to note that this class is the most frequent one among the classes, just after comes "Normal_Weight". Furthermore, "Age" is the first factor with a positive coeficient suggesting that among this class people are on average 0.52 more likely to be older than the populations in the other classes.
#
# . *Overweight Level II*: Here **Demographic** is the most prominent sub-category. Here with a coef of 0.9 "Age" has more weight for this class than the previous one, suggesting that on average the population in this class is older than in the previous one.
#
# . *Obesity type I*: for this class **Dietary** and **Demographic** influence the most. !st is the FCVC (Vegetables consumption Frq) with a coef = 1.84. This is a bit weird as it would say that this class consume on average more frequently vegetables but do not snack that much compared to the other classes (coef = -0.96).
#
# . *Obesity type II*: Here snacking also has a negative impact (-0.5) however less prominent than the previous class. **Dietary** (CAEC_coef = -0.5, FCVC_coef = -0.44) and **Lifestyle** (SCC_Coef = 0.4, CALC_coef = 0.33, SMOKE_coef = -0.27) have the most impact.
#
# . *Obesity type III*: **Dietary and demographic** are here the most prevalent. Interestingly, family history only arrives second in the most positive factors.

# %% [markdown]
# ### **Age**
# To understand better the feature importance for each class, I will focus now on the feature "Age" (from **Demographic**). this feature appears negatively (*Insufficient_Weight*) or positively (*Overweight_Level_II*, *Obesity_Type_III*, *Overweight_Level_I*).
# I will therefore analyse the age distribution relative to each class.

# %%
sns.histplot(new_obesity["Age"], bins=20)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# The distribution of age, which as shown before fits with the original data, is skewed. Hence, if there are differences between the classes, they may not be significant.

# %%
print(df_coefs["Age"].sort_values(ascending=False))
# Out:
# Overweight_Level_II    1.027559
# Obesity_Type_III       0.690485
# Overweight_Level_I     0.578672
# Obesity_Type_II        0.042501
# Obesity_Type_I        -0.044793
# Normal_Weight         -0.408724
# Insufficient_Weight   -1.885699
# Name: Age, dtype: float64

# %% [markdown]
# If we believe the model, the oldest population should be amongst the Overweight_Level_II while the youngest population should be amongst the Insuficient_Weight.

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,6))
sns.violinplot(y="Age", data=new_obesity, ax=ax1)
sns.violinplot(x="NObeyesdad", y="Age", data=new_obesity, ax=ax2)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Obesity_type_I has the least coef value for the Age feature. We can see why by looking at the violin plot. This class contains all the ages without the presence of a clear subpopulation.

# %% [markdown]
# The distributions are different between these 4 categories.
# If we look at the shape of the violins, we can see that most of the insufficient_weight are under 20 and overall the class is compacted to the narrowest age window.
# This is not the case for Overweight_Leevel_1 & 2. Both classes show having the "oldest" people.

# %%
new_obesity["Age"].describe()
# Out:
# count    1107.000000
# mean       22.737398
# std         5.880737
# min        14.000000
# 25%        19.000000
# 50%        21.000000
# 75%        23.494027
# max        55.246250
# Name: Age, dtype: float64

# %%
sum_stat_Age_per_class = new_obesity.groupby("NObeyesdad")["Age"].describe()
sum_stat_Age_per_class
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\3759887720.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sum_stat_Age_per_class = new_obesity.groupby("NObeyesdad")["Age"].describe()
#                      count       mean       std        min        25%  \
# NObeyesdad
# Insufficient_Weight  268.0  19.556097  2.035393  16.000000  18.000000
# Normal_Weight        297.0  21.410405  4.311043  14.000000  19.000000
# Overweight_Level_I   283.0  23.266905  5.669388  16.370009  19.780428
# Overweight_Level_II  188.0  27.078992  7.438216  17.000000  21.783067
# Obesity_Type_I        48.0  27.031916  8.659200  15.000000  21.000000
# Obesity_Type_II       12.0  28.318257  6.744806  20.000000  24.450000
# Obesity_Type_III      11.0  23.421787  2.902871  18.000000  21.851765
#
#                            50%        75%        max
# NObeyesdad
# Insufficient_Weight  19.088157  20.747892  32.383858
# Normal_Weight        20.800000  22.200000  51.000000
# Overweight_Level_I   21.198217  24.154416  55.000000
# Overweight_Level_II  24.715659  31.441053  55.246250
# Obesity_Type_I       23.000000  32.147810  52.000000
# Obesity_Type_II      25.087426  30.500000  41.000000
# Obesity_Type_III     23.518516  25.112663  28.900566

# %%
classes_age_test = multiple_MannWitU(new_obesity, col_name="Age", target_col="NObeyesdad")
classes_age_test
# Out:
# {('Insufficient_Weight', 'Normal_Weight'): 2.1175315832380035e-08,
#  ('Insufficient_Weight', 'Overweight_Level_I'): 5.1819604058461805e-23,
#  ('Insufficient_Weight', 'Overweight_Level_II'): 1.346726576451526e-41,
#  ('Insufficient_Weight', 'Obesity_Type_I'): 2.3677412539913156e-11,
#  ('Insufficient_Weight', 'Obesity_Type_II'): 1.3228827271698578e-06,
#  ('Insufficient_Weight', 'Obesity_Type_III'): 0.0008026853866108003,
#  ('Normal_Weight', 'Overweight_Level_I'): 0.00023564682802022687,
#  ('Normal_Weight', 'Overweight_Level_II'): 5.404849441550585e-23,
#  ('Normal_Weight', 'Obesity_Type_I'): 1.737050267021576e-05,
#  ('Normal_Weight', 'Obesity_Type_II'): 0.00032015376641746904,
#  ('Normal_Weight', 'Obesity_Type_III'): 0.15315650179058393,
#  ('Overweight_Level_I', 'Overweight_Level_II'): 1.018670354061338e-10,
#  ('Overweight_Level_I', 'Obesity_Type_I'): 0.0348612058874197,
#  ('Overweight_Level_I', 'Obesity_Type_II'): 0.01852172984837796,
#  ('Overweight_Level_I', 'Obesity_Type_III'): 2.4994681738308104,
#  ('Overweight_Level_II', 'Obesity_Type_I'): 11.691741723217945,
#  ('Overweight_Level_II', 'Obesity_Type_II'): 6.297418731734803,
#  ('Overweight_Level_II', 'Obesity_Type_III'): 4.295984787780564,
#  ('Obesity_Type_I', 'Obesity_Type_II'): 3.751473901410724,
#  ('Obesity_Type_I', 'Obesity_Type_III'): 9.61919555214014,
#  ('Obesity_Type_II', 'Obesity_Type_III'): 1.4551769021260035}

# %% [markdown]
# the distribution of age of the *Insuficient_Weight* class is significantly different from all the other classes. This is not the case for the other groups. This is the reason why for a large group like this one, "Age" has such a high absolute value compared to the other features.
# On the other hand, *Overweight_Level_II* which also has a relatively high "Age" coeficient, cannot reach significance with the small size classes. Hence, although this feature is important, it is not enough alone to discriminate this class from all the other classes.

# %% [markdown]
# As I will focus later on gender and snacking later, I will not focus on these features here.
# However, in general, none of the features show a clear demarcation allowing us to make a clear cut on which features help more to discriminate a class from another.
# One way to demonstrate this is to apply an unsupervised ML used for dimension reduction.

# %% [markdown]
# ### **PCA**
# PCA is an unsupervised ML for dimension reduction. We can easily apply this method and see whether we have a few principal components that would explain most of the dataset variance. If so, among these PCA we can look at the features with the highest weight.

# %%
pca = PCA()
pca.fit(X_scale)
explained_var = pca.explained_variance_ratio_

# %%
sns.barplot(x=np.arange(1,len(explained_var)+1), y=explained_var)
plt.show()

# %% [markdown]
# There are no principal components that strike fromt he others. The best principal component explains alone only ~16% of the variance, while the the worse principal component explains ~5%.

# %%
pc_1_to_7 = explained_var[:7].sum()
print(f"The explained variance of the first 7 principal components is {pc_1_to_7}")
# Out:
# The explained variance of the first 7 principal components is 0.6811861569082649

# %%
princp_comp = pca.components_
princp_comp_df = pd.DataFrame(princp_comp, columns=X_mod.columns, index=[f"PC_{i}" for i in range(1,len(princp_comp)+1)])
princp_comp_df.head(7)
# Out:
#         Gender       Age    Height  family_history_with_overweight      FCVC  \
# PC_1  0.464733  0.133820  0.532750                        0.340242 -0.071423
# PC_2 -0.112240  0.620609 -0.144156                        0.130861  0.113351
# PC_3 -0.204928 -0.003803  0.054700                       -0.126797  0.569752
# PC_4  0.090921 -0.007577 -0.064886                       -0.075435  0.159491
# PC_5 -0.015143  0.044911  0.144204                        0.114876  0.072830
# PC_6 -0.321122  0.084140 -0.213279                        0.515903 -0.114723
# PC_7 -0.060584  0.040501 -0.097479                       -0.393790 -0.363987
#
#            NCP     SMOKE      CH2O       SCC       FAF       TUE  CALC_num  \
# PC_1  0.266273  0.010831  0.309411 -0.179044  0.255263 -0.028126 -0.019403
# PC_2 -0.186783  0.101230 -0.126642 -0.080381 -0.263688 -0.411262 -0.046203
# PC_3  0.241366 -0.067069  0.126293  0.338244  0.434709 -0.207119 -0.280802
# PC_4 -0.367315  0.299028  0.451018  0.351324  0.120711 -0.248799  0.359060
# PC_5  0.231496  0.652765 -0.198714  0.160581 -0.094016  0.191266  0.453640
# PC_6  0.010278  0.213957  0.257084  0.254882 -0.006193  0.446240 -0.399714
# PC_7  0.429480  0.038859 -0.227150  0.348285  0.170670  0.031717  0.057670
#
#       CAEC_num  MTRANS_num
# PC_1 -0.148387   -0.272525
# PC_2 -0.024009   -0.492422
# PC_3  0.310610   -0.118274
# PC_4 -0.416313    0.162608
# PC_5  0.401307   -0.035121
# PC_6 -0.166105   -0.039040
# PC_7 -0.426838   -0.350880

# %%
for col in princp_comp_df.columns:
    princp_comp_df[col] = princp_comp_df[col].apply(lambda x: abs(x))

# %%
PC_1 = princp_comp_df.loc["PC_1"].sort_values(ascending=False)
PC_2 = princp_comp_df.loc["PC_2"].sort_values(ascending=False)
PC_3 = princp_comp_df.loc["PC_3"].sort_values(ascending=False)
PC_4 = princp_comp_df.loc["PC_4"].sort_values(ascending=False)
PC_5 = princp_comp_df.loc["PC_5"].sort_values(ascending=False)
PC_6 = princp_comp_df.loc["PC_6"].sort_values(ascending=False)
PC_7 = princp_comp_df.loc["PC_7"].sort_values(ascending=False)
print(PC_1.index[0])
PC_list = [PC_1,PC_2,PC_3,PC_4,PC_5,PC_6,PC_7]
for pc in PC_list:
    pc_max = pc.index[0]
    print(f"The first 3 features with the highest loading in the principal component {pc.name} are {pc[:3].index}")
# Out:
# Height
# The first 3 features with the highest loading in the principal component PC_1 are Index(['Height', 'Gender', 'family_history_with_overweight'], dtype='object')
# The first 3 features with the highest loading in the principal component PC_2 are Index(['Age', 'MTRANS_num', 'TUE'], dtype='object')
# The first 3 features with the highest loading in the principal component PC_3 are Index(['FCVC', 'FAF', 'SCC'], dtype='object')
# The first 3 features with the highest loading in the principal component PC_4 are Index(['CH2O', 'CAEC_num', 'NCP'], dtype='object')
# The first 3 features with the highest loading in the principal component PC_5 are Index(['SMOKE', 'CALC_num', 'CAEC_num'], dtype='object')
# The first 3 features with the highest loading in the principal component PC_6 are Index(['family_history_with_overweight', 'TUE', 'CALC_num'], dtype='object')
# The first 3 features with the highest loading in the principal component PC_7 are Index(['NCP', 'CAEC_num', 'family_history_with_overweight'], dtype='object')

# %%
@widgets.interact
def highest_loading_feature(pc = [f"PC_{i}" for i in range(1,len(princp_comp)+1)]):
    print(princp_comp_df.loc[pc].sort_values(ascending=False).index[0])
# Out:
# interactive(children=(Dropdown(description='pc', options=('PC_1', 'PC_2', 'PC_3', 'PC_4', 'PC_5', 'PC_6', 'PC_…

# %%
dict_best_feat = {}
for pc in princp_comp_df.index:
    best_feat = princp_comp_df.loc[pc].sort_values(ascending=False).index[0]
    if best_feat not in dict_best_feat:
        dict_best_feat[best_feat] = 1
    else:
        dict_best_feat[best_feat] += 1

sorted_dict_best_feat = dict(sorted(dict_best_feat.items(), key=lambda x: x[1], reverse=True))
print(sorted_dict_best_feat)
# Out:
# {'Height': 2, 'Age': 2, 'FCVC': 2, 'SMOKE': 2, 'family_history_with_overweight': 2, 'CH2O': 1, 'NCP': 1, 'SCC': 1, 'FAF': 1}

# %% [markdown]
# The first 5 principal components only explain 54% of the variance.
# Furthermore, none of these 5 principal components have the same feature with the highest loading.
# Lastly, "Height", "Age", "FCVC" and "SMOKE" appear to be the highest only in 2 principal component each.
#
# We can therefore conclude that no particular features have more weight compared to the other to discriminate the classes.
# Nonetheless, because "Height", "Age" and "FCVC" are the 3 "best" features from the first 3 "best" principal components, we could perhaps suggest that these features would be more prevalent than the others (if anything).

# %% [markdown]
# ### **FCVC: Vegetables Consumption frequency**
# This feature gave non-intuitive coeficients. One would think that if anything it would have a negative weight for the overweight and obese classes, however that was not what we see. Hence, I wanted to investigated.

# %%
print(df_coefs["FCVC"].sort_values(ascending=False))
# Out:
# Obesity_Type_I         1.677874
# Overweight_Level_II    0.322072
# Insufficient_Weight    0.000262
# Normal_Weight         -0.394093
# Obesity_Type_II       -0.440586
# Obesity_Type_III      -0.511876
# Overweight_Level_I    -0.653653
# Name: FCVC, dtype: float64

# %%
new_obesity["FCVC"].describe()
# Out:
# count    1107.000000
# mean        2.339680
# std         0.550695
# min         1.000000
# 25%         2.000000
# 50%         2.029634
# 75%         3.000000
# max         3.000000
# Name: FCVC, dtype: float64

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize = (12,6))
sns.violinplot(y=new_obesity["FCVC"], ax=ax1)
sns.violinplot(x="NObeyesdad", y="FCVC", data=new_obesity, ax=ax2)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Most of the people have responded a frequency of vegetable consumption of 2. However, there is a non-negligeable proportion of people who has responded 3.
# Among the Insuficient_Weight class, most of the people declare eating vegetables with a frq>2.
# Nonetheless, the distribution of FCVC in Obesity_Type_I doesn't seem that different from Overweight_Level_I and II. Knowing that Obesity_Type_I is largely in minority compared to these 2 classes, it is difficult to understand why this fetaure alone can have such a high positive coeficient level.

# %%
new_obesity["NObeyesdad"].value_counts()
# Out:
# NObeyesdad
# Normal_Weight          297
# Overweight_Level_I     283
# Insufficient_Weight    268
# Overweight_Level_II    188
# Obesity_Type_I          48
# Obesity_Type_II         12
# Obesity_Type_III        11
# Name: count, dtype: int64

# %%
new_obesity.groupby("NObeyesdad")["FCVC"].describe()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\4211282750.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   new_obesity.groupby("NObeyesdad")["FCVC"].describe()
#                      count      mean       std  min  25%       50%       75%  \
# NObeyesdad
# Insufficient_Weight  268.0  2.478161  0.586847  1.0  2.0  2.708316  3.000000
# Normal_Weight        297.0  2.329762  0.589115  1.0  2.0  2.000000  3.000000
# Overweight_Level_I   283.0  2.273608  0.482826  1.0  2.0  2.000466  2.789784
# Overweight_Level_II  188.0  2.246693  0.476751  1.0  2.0  2.000000  2.691017
# Obesity_Type_I        48.0  2.211041  0.543414  1.0  2.0  2.000000  3.000000
# Obesity_Type_II       12.0  2.416667  0.668558  1.0  2.0  2.500000  3.000000
# Obesity_Type_III      11.0  3.000000  0.000000  3.0  3.0  3.000000  3.000000
#
#                      max
# NObeyesdad
# Insufficient_Weight  3.0
# Normal_Weight        3.0
# Overweight_Level_I   3.0
# Overweight_Level_II  3.0
# Obesity_Type_I       3.0
# Obesity_Type_II      3.0
# Obesity_Type_III     3.0

# %%
FCVC_p_mannW = multiple_MannWitU(new_obesity, col_name="FCVC", target_col="NObeyesdad")
FCVC_p_mannW
# Out:
# {('Insufficient_Weight', 'Normal_Weight'): 0.49432530940866404,
#  ('Insufficient_Weight', 'Overweight_Level_I'): 1.7206273261706063e-06,
#  ('Insufficient_Weight', 'Overweight_Level_II'): 6.846335194059712e-06,
#  ('Insufficient_Weight', 'Obesity_Type_I'): 0.08293524040545858,
#  ('Insufficient_Weight', 'Obesity_Type_II'): 18.61684022046392,
#  ('Insufficient_Weight', 'Obesity_Type_III'): 0.0013469019537895321,
#  ('Normal_Weight', 'Overweight_Level_I'): 2.8189364708782136,
#  ('Normal_Weight', 'Overweight_Level_II'): 2.3875727470631665,
#  ('Normal_Weight', 'Obesity_Type_I'): 4.177940149503384,
#  ('Normal_Weight', 'Obesity_Type_II'): 11.739063308331488,
#  ('Normal_Weight', 'Obesity_Type_III'): 0.002562354839497196,
#  ('Overweight_Level_I', 'Overweight_Level_II'): 11.504110469866376,
#  ('Overweight_Level_I', 'Obesity_Type_I'): 8.33632586046358,
#  ('Overweight_Level_I', 'Obesity_Type_II'): 5.375851250621944,
#  ('Overweight_Level_I', 'Obesity_Type_III'): 1.4512924721425022e-05,
#  ('Overweight_Level_II', 'Obesity_Type_I'): 11.349580258302925,
#  ('Overweight_Level_II', 'Obesity_Type_II'): 5.0005541270651666,
#  ('Overweight_Level_II', 'Obesity_Type_III'): 1.8774581286549806e-05,
#  ('Obesity_Type_I', 'Obesity_Type_II'): 5.155613887033613,
#  ('Obesity_Type_I', 'Obesity_Type_III'): 0.0005356012249730344,
#  ('Obesity_Type_II', 'Obesity_Type_III'): 0.18967838375239013}

# %% [markdown]
# Alone FCVC doesn't mean anything. Perhaps should we look in relation with another feature.

# %%
sns.scatterplot(x="Height", y="FCVC", data=new_obesity, hue="NObeyesdad")
plt.legend(loc="center left", bbox_to_anchor=(1,0.5))
plt.show()

# %%
@widgets.interact
def scatterplot_height_fcvc(weight_class = classes):
    sns.scatterplot(x="Height", y="FCVC", data=new_obesity[new_obesity["NObeyesdad"] == weight_class])
    plt.legend(loc="center left", bbox_to_anchor=(1,0.5))
    plt.show()
# Out:
# interactive(children=(Dropdown(description='weight_class', options=('Insufficient_Weight', 'Normal_Weight', 'O…

# %% [markdown]
# There is perhaps a negative correlation between FCVC and TUE (Tech device usage) and Gender.

# %% [markdown]
# ### **NCP: Number of daily meals**

# %%
df_coefs["NCP"].sort_values(ascending=False)
# Out:
# Obesity_Type_I         0.575755
# Insufficient_Weight    0.270908
# Normal_Weight          0.104982
# Overweight_Level_II   -0.162764
# Obesity_Type_II       -0.185306
# Overweight_Level_I    -0.247308
# Obesity_Type_III      -0.356269
# Name: NCP, dtype: float64

# %%
new_obesity["NCP"].describe()
# Out:
# count    1107.000000
# mean        2.667118
# std         0.904456
# min         1.000000
# 25%         2.365304
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: NCP, dtype: float64

# %%
print(df_coefs["NCP"].sort_values(ascending=False))
# Out:
# Obesity_Type_I         0.575755
# Insufficient_Weight    0.270908
# Normal_Weight          0.104982
# Overweight_Level_II   -0.162764
# Obesity_Type_II       -0.185306
# Overweight_Level_I    -0.247308
# Obesity_Type_III      -0.356269
# Name: NCP, dtype: float64

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize=(12,6))
sns.violinplot(y=new_obesity["NCP"], ax=ax1)
sns.violinplot(x="NObeyesdad", y="NCP", data=new_obesity, ax=ax2)
plt.xticks(rotation=90)
plt.show()

# %%
NCP_p_MannW = multiple_MannWitU(new_obesity, col_name="NCP", target_col="NObeyesdad")
NCP_p_MannW
# Out:
# {('Insufficient_Weight', 'Normal_Weight'): 0.0006009194417477849,
#  ('Insufficient_Weight', 'Overweight_Level_I'): 2.2149713124888606e-07,
#  ('Insufficient_Weight', 'Overweight_Level_II'): 8.952430608890529e-12,
#  ('Insufficient_Weight', 'Obesity_Type_I'): 0.005076784211947424,
#  ('Insufficient_Weight', 'Obesity_Type_II'): 2.6311696144847168,
#  ('Insufficient_Weight', 'Obesity_Type_III'): 7.70037232026899,
#  ('Normal_Weight', 'Overweight_Level_I'): 0.20974177528085802,
#  ('Normal_Weight', 'Overweight_Level_II'): 4.282692105767493e-06,
#  ('Normal_Weight', 'Obesity_Type_I'): 1.8421787551945135,
#  ('Normal_Weight', 'Obesity_Type_II'): 12.597616774432769,
#  ('Normal_Weight', 'Obesity_Type_III'): 11.251403637823245,
#  ('Overweight_Level_I', 'Overweight_Level_II'): 1.7098839966888306,
#  ('Overweight_Level_I', 'Obesity_Type_I'): 18.198367236041793,
#  ('Overweight_Level_I', 'Obesity_Type_II'): 17.816410682022493,
#  ('Overweight_Level_I', 'Obesity_Type_III'): 3.8013078028912255,
#  ('Overweight_Level_II', 'Obesity_Type_I'): 3.7433522936852834,
#  ('Overweight_Level_II', 'Obesity_Type_II'): 7.375373106945669,
#  ('Overweight_Level_II', 'Obesity_Type_III'): 0.2217988631696173,
#  ('Obesity_Type_I', 'Obesity_Type_II'): 15.95172463947354,
#  ('Obesity_Type_I', 'Obesity_Type_III'): 2.1971968437929683,
#  ('Obesity_Type_II', 'Obesity_Type_III'): 6.868219548039194}

# %%
new_obesity.groupby("NObeyesdad")["NCP"].describe()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\914698619.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   new_obesity.groupby("NObeyesdad")["NCP"].describe()
#                      count      mean       std  min       25%  50%       75%  \
# NObeyesdad
# Insufficient_Weight  268.0  2.906549  0.903473  1.0  2.998302  3.0  3.532033
# Normal_Weight        297.0  2.733381  0.876733  1.0  3.000000  3.0  3.000000
# Overweight_Level_I   283.0  2.520042  0.960565  1.0  1.401731  3.0  3.000000
# Overweight_Level_II  188.0  2.465740  0.792513  1.0  1.893341  3.0  3.000000
# Obesity_Type_I        48.0  2.520833  0.898926  1.0  2.500000  3.0  3.000000
# Obesity_Type_II       12.0  2.583333  0.996205  1.0  2.500000  3.0  3.000000
# Obesity_Type_III      11.0  3.000000  0.000000  3.0  3.000000  3.0  3.000000
#
#                      max
# NObeyesdad
# Insufficient_Weight  4.0
# Normal_Weight        4.0
# Overweight_Level_I   4.0
# Overweight_Level_II  4.0
# Obesity_Type_I       4.0
# Obesity_Type_II      4.0
# Obesity_Type_III     3.0

# %% [markdown]
# ### **Conclusion**
# Overall, both **Demographic** ("Age", "Height" and "Family_history_with_overweight") and **Dietary** ("FCVC", "CAEC") have a relative importance to discriminate between classes.
# However, the PCA told us that there are no strong features. That is also the reason why the coeficients for the logistic regression were not so high in general (the highest being "Age" with an absolute value of 1.84).

# %% [markdown]
# ## **2) Difference between males and females**
# The dataset can be divided into 2 genders: males and females.
# Although in general (appart from "Age") no features show particular weight into classes discrimination, we can still ask whether if we separate the 2 genders, we will see a difference.

# %%
new_obesity["Gender"].value_counts()
# Out:
# Gender
# Female    652
# Male      455
# Name: count, dtype: int64

# %%
train_set_df["Gender"].value_counts(dropna=False, normalize=True)
# Out:
# Gender
# Male      0.347787
# Female    0.337850
# NaN       0.314363
# Name: proportion, dtype: float64

# %% [markdown]
# Before imputing we had basically 1/3 of each (Male, female and Nan).
# After imputing we have now more Females than Males. And this was true even after imputing without the output variable.
# This would suggest that the combination of the other features helped in determinig the gender of the person.
# I woud say this is encouraging as the 2 populations looks to be of different compositions.

# %%
train_set_df["NObeyesdad"] = train_set_df["NObeyesdad"].cat.reorder_categories(new_categories=order_classes, ordered=True)

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize=(10,5))
sns.countplot(x="NObeyesdad", data=train_set_df, hue="Gender", ax=ax1)
ax1.set_title("Original Data")
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
sns.countplot(x="NObeyesdad", data=new_obesity, hue="Gender", ax=ax2)
ax2.set_title("imputed Data")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
plt.show()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\2324649428.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\2324649428.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# Before imputing, apart from *Insuficient_Weight* and *Obesity_type_III*, males were majoritaire in all the other classes. After, imputing we can see that they are minoritaire in all classes (Except *Obesity_Type_I* where they are in equal number and *Obesity_Type_II* where they are slightly majoritaire).
# The imputer hasn't respected the distribution of genders, suggesting that other factors (features) influence the gender determination.
# It is important to note that I obtain similar results after imputing without the output variable "NObeyesdad", confirming that this new distribution was deducted from the other features and not fro the output variable.

# %%
train_set_df.groupby("Gender", observed=True)["NObeyesdad"].value_counts(dropna=False)
# Out:
# Gender  NObeyesdad
# Female  Insufficient_Weight    127
#         Overweight_Level_I      91
#         Normal_Weight           88
#         Overweight_Level_II     47
#         Obesity_Type_I          10
#         Obesity_Type_III         8
#         Obesity_Type_II          3
# Male    Normal_Weight          106
#         Overweight_Level_I      99
#         Overweight_Level_II     79
#         Insufficient_Weight     72
#         Obesity_Type_I          22
#         Obesity_Type_II          7
#         Obesity_Type_III         0
# Name: count, dtype: int64

# %%
new_obesity.groupby("Gender")["NObeyesdad"].value_counts(dropna=False)
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\1265887194.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   new_obesity.groupby("Gender")["NObeyesdad"].value_counts(dropna=False)
# Gender  NObeyesdad
# Female  Normal_Weight          185
#         Insufficient_Weight    180
#         Overweight_Level_I     155
#         Overweight_Level_II     94
#         Obesity_Type_I          24
#         Obesity_Type_III        11
#         Obesity_Type_II          3
# Male    Overweight_Level_I     128
#         Normal_Weight          112
#         Overweight_Level_II     94
#         Insufficient_Weight     88
#         Obesity_Type_I          24
#         Obesity_Type_II          9
#         Obesity_Type_III         0
# Name: count, dtype: int64

# %% [markdown]
# I will therefore divide the dataset into 2 sub-datasets: males and females and run again a logistic regression to see the feature importances by their coeficients.

# %%
print(X.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   int32
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   int32
#  5   FAVC                            1107 non-null   int32
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   int32
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   int32
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC_num                        1107 non-null   int32
#  15  CAEC_num                        1107 non-null   int32
#  16  MTRANS_num                      1107 non-null   int32
#  17  NObeyesdad_num                  1107 non-null   int32
# dtypes: float64(9), int32(9)
# memory usage: 116.9 KB
# None

# %%
X["NObeyesdad"] = Encod_y.reverse_transform(X,"NObeyesdad_num")
X.drop("NObeyesdad_num", axis=1, inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1107 non-null   int32
#  1   Age                             1107 non-null   float64
#  2   Height                          1107 non-null   float64
#  3   Weight                          1107 non-null   float64
#  4   family_history_with_overweight  1107 non-null   int32
#  5   FAVC                            1107 non-null   int32
#  6   FCVC                            1107 non-null   float64
#  7   NCP                             1107 non-null   float64
#  8   SMOKE                           1107 non-null   int32
#  9   CH2O                            1107 non-null   float64
#  10  SCC                             1107 non-null   int32
#  11  FAF                             1107 non-null   float64
#  12  TUE                             1107 non-null   float64
#  13  BMI                             1107 non-null   float64
#  14  CALC_num                        1107 non-null   int32
#  15  CAEC_num                        1107 non-null   int32
#  16  MTRANS_num                      1107 non-null   int32
#  17  NObeyesdad                      1107 non-null   object
# dtypes: float64(9), int32(8), object(1)
# memory usage: 121.2+ KB

# %%
X["NObeyesdad"] = X["NObeyesdad"].astype("category")
X["NObeyesdad"] = X["NObeyesdad"].cat.reorder_categories(classes)

# %%
sns.countplot(x="NObeyesdad", data=X, hue="Gender")
plt.xticks(rotation=90)
plt.show()

# %%
list_binom_bool_dict[0]
# Out:
# {'Female': 0, 'Male': 1}

# %%
X_fem = X[X["Gender"] == 0].copy()
X_mal = X[X["Gender"] == 1].copy()
y_fem = X_fem["NObeyesdad"]
y_mal = X_mal["NObeyesdad"]
X_fem.drop(["NObeyesdad","Weight","FAVC","Gender","BMI"], axis=1, inplace=True)
X_mal.drop(["NObeyesdad","Weight","FAVC","Gender","BMI"], axis=1, inplace=True)

# %%
y_mal.value_counts()
# Out:
# NObeyesdad
# Overweight_Level_I     128
# Normal_Weight          112
# Overweight_Level_II     94
# Insufficient_Weight     88
# Obesity_Type_I          24
# Obesity_Type_II          9
# Obesity_Type_III         0
# Name: count, dtype: int64

# %%
y_mal = y_mal.cat.remove_categories(["Obesity_Type_III"])

order_mal_classes = ["Insufficient_Weight","Normal_Weight","Overweight_Level_I","Overweight_Level_II","Obesity_Type_I","Obesity_Type_II"]
y_mal = y_mal.cat.reorder_categories(order_mal_classes, ordered=True)
y_classes = y_mal.cat.categories

# %%
y_fem.value_counts()
# Out:
# NObeyesdad
# Normal_Weight          185
# Insufficient_Weight    180
# Overweight_Level_I     155
# Overweight_Level_II     94
# Obesity_Type_I          24
# Obesity_Type_III        11
# Obesity_Type_II          3
# Name: count, dtype: int64

# %%
dict_y
# Out:
# {'Insufficient_Weight': 0,
#  'Normal_Weight': 1,
#  'Overweight_Level_I': 2,
#  'Overweight_Level_II': 3,
#  'Obesity_Type_I': 4,
#  'Obesity_Type_II': 5,
#  'Obesity_Type_III': 6}

# %%
female_logReg = LogisticRegression(max_iter=1000)
male_logReg = LogisticRegression(max_iter=1000)

X_fem_scale = stScale.fit_transform(X_fem)
X_mal_scale = stScale.fit_transform(X_mal)

female_logReg.fit(X_fem_scale, y_fem)
male_logReg.fit(X_mal_scale, y_mal)

fem_coefs = female_logReg.coef_
mal_coefs = male_logReg.coef_

# %%
df_fem_coefs = pd.DataFrame(fem_coefs, columns=X_fem.columns, index=classes)
df_mal_coefs = pd.DataFrame(mal_coefs, columns=X_mal.columns, index=y_classes)

# %% [markdown]
# ### **Females**

# %%
@widgets.interact
def most_important_negFeature(weight_class = classes):
    print(most_import_negFeature(df_fem_coefs, weight_class))
# Out:
# interactive(children=(Dropdown(description='weight_class', options=('Insufficient_Weight', 'Normal_Weight', 'O…

# %%
@widgets.interact
def most_important_posFeature(weight_class = classes):
    print(most_import_posFeature(df_fem_coefs, weight_class))
# Out:
# interactive(children=(Dropdown(description='weight_class', options=('Insufficient_Weight', 'Normal_Weight', 'O…

# %% [markdown]
# ### **Males**

# %%
@widgets.interact
def most_important_negFeature(weight_class = y_classes):
    print(most_import_negFeature(df_mal_coefs, weight_class))
# Out:
# interactive(children=(Dropdown(description='weight_class', options=('Insufficient_Weight', 'Normal_Weight', 'O…

# %%
@widgets.interact
def most_important_posFeature(weight_class = y_classes):
    print(most_import_posFeature(df_mal_coefs, weight_class))
# Out:
# interactive(children=(Dropdown(description='weight_class', options=('Insufficient_Weight', 'Normal_Weight', 'O…

# %% [markdown]
# ### **Females vs Males**

# %%
def dict_3_high_coefs(df, classes):
    df_abs = df.abs()
    dict_coefs = {}
    for cla in classes:
        dict_coefs[cla] = list(df_abs.loc[cla].sort_values(ascending=False).index[:3])
    return dict_coefs

dict_fem_coefs = dict_3_high_coefs(df_fem_coefs, classes)
dict_mal_coefs = dict_3_high_coefs(df_mal_coefs, y_classes)

# %%
@widgets.interact
def best_coef_gender(fem_class = classes, mal_class = y_classes):
    print(f"In females: {dict_fem_coefs[fem_class]};\nIn males: {dict_mal_coefs[mal_class]}")
# Out:
# interactive(children=(Dropdown(description='fem_class', options=('Insufficient_Weight', 'Normal_Weight', 'Over…

# %% [markdown]
# While Age stays in both genders a strong factor for *Insuficient_Weight* and *Overweight_Type_II*, it becomes also a strong one for males *Obesity_Type_II*. However, it is important to note that the male dataset doesn't have the last class *Obesity_Type_III* and has 7 individuals with *Obesity_Type_II* while the females only has 4. Hence, this class is much too small in both gender to make any strong conclusions.
# Nonetheless, *Insuficient_Weight* and *Overweight_Level_II* are large enough to start interpret the numbers.
# In the whole dataset "Age" in *Insuficient_Weight* class has a coef = -1.84, which was the highest absolute value. Now the absolute value of "Age" coef was almost double in the male group (3) but was slightly reduced in the females. This suggests a difference of the distribution of age in this class between males and females.
# On the other hand the "Age" coef for the class *Overweight_Level_II* hasn't changed much. In the whole dataset it is = 0.91, in Female dataset it is =1.15 and in male dataset it is = 1.01. We are therefore not expecting much difference of the age distribution between the 2 genders in this class.

# %%
sns.boxenplot(x="NObeyesdad", y="Age", data=new_obesity, hue="Gender")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We can indeed observe here that the median of Age and its distribution are much reduced in males in the *Insufficient_Weight* class. This allows it to stay significantly younger than the other other classes (even with *Obesity_Type_II* which only has 7 individuals).
# As a consequence, "Age" in the female *Insuficient_Weight* becomes older and although its distribution remains narrow compared to the other classes (still informative for the class determination), it losts significance with other classes, like for example *Normal_Weight*.

# %%
print(y_fem.value_counts(sort=False))
print(y_mal.value_counts(sort=False))
# Out:
# NObeyesdad
# Insufficient_Weight    180
# Normal_Weight          185
# Overweight_Level_I     155
# Overweight_Level_II     94
# Obesity_Type_I          24
# Obesity_Type_II          3
# Obesity_Type_III        11
# Name: count, dtype: int64
# NObeyesdad
# Insufficient_Weight     88
# Normal_Weight          112
# Overweight_Level_I     128
# Overweight_Level_II     94
# Obesity_Type_I          24
# Obesity_Type_II          9
# Name: count, dtype: int64

# %%
males = new_obesity[new_obesity["Gender"] == "Male"].copy()
females = new_obesity[new_obesity["Gender"] == "Female"].copy()
males["NObeyesdad"] = males["NObeyesdad"].cat.remove_categories(["Obesity_Type_III"])

# %%
multiple_MannWitU(males,col_name="Age",target_col="NObeyesdad")
# Out:
# {('Insufficient_Weight', 'Normal_Weight'): 1.3788391336917242e-13,
#  ('Insufficient_Weight', 'Overweight_Level_I'): 9.749933450368282e-25,
#  ('Insufficient_Weight', 'Overweight_Level_II'): 2.0225211054126572e-24,
#  ('Insufficient_Weight', 'Obesity_Type_I'): 1.44823165517202e-07,
#  ('Insufficient_Weight', 'Obesity_Type_II'): 2.355303054587721e-05,
#  ('Normal_Weight', 'Overweight_Level_I'): 0.09144482075984042,
#  ('Normal_Weight', 'Overweight_Level_II'): 2.6480098111418906e-14,
#  ('Normal_Weight', 'Obesity_Type_I'): 0.03641512601959469,
#  ('Normal_Weight', 'Obesity_Type_II'): 0.002071633304683116,
#  ('Overweight_Level_I', 'Overweight_Level_II'): 5.5227206648208205e-12,
#  ('Overweight_Level_I', 'Obesity_Type_I'): 0.4306733813586008,
#  ('Overweight_Level_I', 'Obesity_Type_II'): 0.0053374981982968975,
#  ('Overweight_Level_II', 'Obesity_Type_I'): 6.657373852869412,
#  ('Overweight_Level_II', 'Obesity_Type_II'): 4.684817836596729,
#  ('Obesity_Type_I', 'Obesity_Type_II'): 3.9789016635860013}

# %%
multiple_MannWitU(females,col_name="Age",target_col="NObeyesdad")
# Out:
# {('Insufficient_Weight', 'Normal_Weight'): 0.8045081082206152,
#  ('Insufficient_Weight', 'Overweight_Level_I'): 3.773170320491561e-06,
#  ('Insufficient_Weight', 'Overweight_Level_II'): 7.024193170717814e-17,
#  ('Insufficient_Weight', 'Obesity_Type_I'): 4.700542656820968e-06,
#  ('Insufficient_Weight', 'Obesity_Type_II'): 0.09771467141146445,
#  ('Insufficient_Weight', 'Obesity_Type_III'): 0.00516757478460018,
#  ('Normal_Weight', 'Overweight_Level_I'): 0.014622040959387992,
#  ('Normal_Weight', 'Overweight_Level_II'): 1.2723466152377495e-09,
#  ('Normal_Weight', 'Obesity_Type_I'): 0.002804308013272287,
#  ('Normal_Weight', 'Obesity_Type_II'): 0.7657571488488928,
#  ('Normal_Weight', 'Obesity_Type_III'): 0.24209463761002709,
#  ('Overweight_Level_I', 'Overweight_Level_II'): 0.025329405038153154,
#  ('Overweight_Level_I', 'Obesity_Type_I'): 0.9685012437585417,
#  ('Overweight_Level_I', 'Obesity_Type_II'): 6.857322596320952,
#  ('Overweight_Level_I', 'Obesity_Type_III'): 8.18221594479355,
#  ('Overweight_Level_II', 'Obesity_Type_I'): 20.663760904060826,
#  ('Overweight_Level_II', 'Obesity_Type_II'): 19.083680976631655,
#  ('Overweight_Level_II', 'Obesity_Type_III'): 8.086983424403623,
#  ('Obesity_Type_I', 'Obesity_Type_II'): 11.747326353609505,
#  ('Obesity_Type_I', 'Obesity_Type_III'): 10.217212862849266,
#  ('Obesity_Type_II', 'Obesity_Type_III'): 11.653846153846155}

# %% [markdown]
# ### **PCA**

# %%
#Females
pca.fit(X_fem_scale)
explained_var_fem = pca.explained_variance_ratio_
sns.barplot(x=np.arange(1,len(explained_var_fem)+1), y=explained_var_fem)
plt.show()

# %%
five_xpl_var_fem = explained_var_fem[:7].sum()
print(f"the first 7 principal components explain {five_xpl_var_fem} of the total variance")
# Out:
# the first 7 principal components explain 0.7174564580567814 of the total variance

# %% [markdown]
# Slightly better than when taken together with the males. this suggests some differences between the 2 genders.

# %%
fem_comp = pca.components_
fem_comp_df = pd.DataFrame(fem_comp, columns=X_fem.columns, index=[f"PC_{i}" for i in range(1,len(fem_comp)+1)])
for col in fem_comp_df.columns:
    fem_comp_df[col] = fem_comp_df[col].apply(lambda x: abs(x))

# %%
@widgets.interact
def highest_loading_feature(pc = [f"PC_{i}" for i in range(1,len(fem_comp)+1)]):
    print(fem_comp_df.loc[pc].sort_values(ascending=False).index[0])
# Out:
# interactive(children=(Dropdown(description='pc', options=('PC_1', 'PC_2', 'PC_3', 'PC_4', 'PC_5', 'PC_6', 'PC_…

# %%
fem_dict_best_feat = {}
for pc in fem_comp_df.index:
    best_feat = fem_comp_df.loc[pc].sort_values(ascending=False).index[0]
    if best_feat not in fem_dict_best_feat:
        fem_dict_best_feat[best_feat] = 1
    else:
        fem_dict_best_feat[best_feat] += 1

sorted_fem_dict_best_feat = dict(sorted(fem_dict_best_feat.items(),\
                                        key=lambda x: x[1], reverse=True))
print(sorted_fem_dict_best_feat)
# Out:
# {'Age': 2, 'FAF': 2, 'Height': 1, 'FCVC': 1, 'CH2O': 1, 'CALC_num': 1, 'CAEC_num': 1, 'NCP': 1, 'TUE': 1, 'SCC': 1, 'family_history_with_overweight': 1}

# %%
#Males
pca.fit(X_mal_scale)
explained_var_mal = pca.explained_variance_ratio_
sns.barplot(x=np.arange(1,len(explained_var_mal)+1), y=explained_var_mal)
plt.show()

# %%
five_xpl_var_mal = explained_var_mal[:7].sum()
print(f"the first 7 principal components explain {five_xpl_var_mal} of the total variance")
# Out:
# the first 7 principal components explain 0.7161942995949806 of the total variance

# %%
male_prin_comp = pca.components_
male_pc_df = pd.DataFrame(male_prin_comp, columns=X_mal.columns,\
                          index=[f"PC_{i}" for i in range(1,len(male_prin_comp)+1)])

# %%
male_pc_df.head()
# Out:
#            Age    Height  family_history_with_overweight      FCVC       NCP  \
# PC_1 -0.069999  0.471652                        0.242175  0.310508  0.427852
# PC_2 -0.490342 -0.042968                        0.108097 -0.179328  0.261250
# PC_3 -0.381390 -0.232790                       -0.325747  0.239663 -0.047524
# PC_4 -0.179504  0.148180                        0.006532  0.252806 -0.074981
# PC_5  0.029365  0.171483                        0.432325 -0.316774  0.037020
#
#          SMOKE      CH2O       SCC       FAF       TUE  CALC_num  CAEC_num  \
# PC_1 -0.056305 -0.017806  0.103432  0.373603  0.108199 -0.311458  0.247095
# PC_2 -0.097716 -0.137169 -0.171671 -0.110776  0.580562  0.054908  0.217298
# PC_3 -0.325810  0.401754 -0.022060  0.399777 -0.042915 -0.276124 -0.322956
# PC_4  0.496012  0.130970  0.566591  0.192862  0.020027  0.388832 -0.020574
# PC_5  0.147047  0.560530 -0.267454  0.107121  0.183797  0.204950 -0.405887
#
#       MTRANS_num
# PC_1   -0.333150
# PC_2    0.433857
# PC_3    0.155849
# PC_4    0.320669
# PC_5   -0.147503

# %%
@widgets.interact
def highest_loading_feature(pc = [f"PC_{i}" for i in range(1,len(male_prin_comp)+1)]):
    print(male_pc_df.loc[pc].sort_values(ascending=False).index[0])
# Out:
# interactive(children=(Dropdown(description='pc', options=('PC_1', 'PC_2', 'PC_3', 'PC_4', 'PC_5', 'PC_6', 'PC_…

# %%
male_dict_best_feat = {}
for pc in male_pc_df.index:
    best_feat = male_pc_df.loc[pc].sort_values(ascending=False).index[0]
    if best_feat not in male_dict_best_feat:
        male_dict_best_feat[best_feat] = 1
    else:
        male_dict_best_feat[best_feat] += 1

sort_male_dict = dict(sorted(male_dict_best_feat.items(), key=lambda x: x[1], reverse=True))
print(sort_male_dict)
# Out:
# {'TUE': 2, 'CH2O': 2, 'SCC': 2, 'Height': 1, 'SMOKE': 1, 'family_history_with_overweight': 1, 'CALC_num': 1, 'FCVC': 1, 'FAF': 1, 'MTRANS_num': 1}

# %% [markdown]
# Dividing the Dataset by Gender increases in general the weight of the features.
# "Age" is the most informative as the coef for male *Insuficient_Weight* is now = -3 and the distribution even less variable.
# Interestingly, among the males now features belonging to **Lifestyle** ("TUE" notably) are now taking more weight.
# Although again no particular features (appart from "Age" for *Insufficient_Weight*) bear enough weight to stand out, their combinations are different between the 2 Genders.

# %% [markdown]
# ### **Height**

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize=(12,6))
sns.scatterplot(x="Age", y="Height", data=females, hue="NObeyesdad", ax=ax1)
ax1.set_xlim(15,55)
ax1.set_ylim(1.45,2)
ax1.set_title("Females")
plt.legend(loc="center left", bbox_to_anchor=(1,0.5))
sns.scatterplot(x="Age", y="Height", data=males, hue="NObeyesdad", ax=ax2)
ax2.set_ylim(1.45,2)
ax2.set_xlim(15,55)
ax2.set_title("Males")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### **Take a specific look at** ***Obesity_Type_III***

# %%
orig_ObIII = train_set_df[train_set_df["NObeyesdad"] == "Obesity_Type_III"].copy()
imputed_ObIII = new_obesity[new_obesity["NObeyesdad"] == "Obesity_Type_III"].copy()

orig_ObIII
# Out:
#       ID  Gender        Age    Height      Weight  \
# 200  203  Female        NaN  1.560000  102.000000
# 342  345     NaN  18.000000  1.870000  149.424703
# 401  404  Female        NaN  1.618972  112.000000
# 496  499  Female  25.196214  1.686306  121.509983
# 497  500  Female        NaN  1.683124  126.673780
# 498  501  Female        NaN  1.622397  110.792630
# 499  502     NaN  21.853826  1.755643  137.796884
# 500  503  Female  21.900120  1.843419  165.057269
# 501  504  Female        NaN  1.764462  133.034410
# 502  505  Female  26.000000  1.630927  111.485516
# 504  507     NaN  21.849705  1.770612  133.963349
#
#     family_history_with_overweight FAVC  FCVC  NCP       CAEC SMOKE      CH2O  \
# 200                            yes  NaN   3.0  3.0  Sometimes   yes  1.000000
# 342                            yes  yes   3.0  3.0        NaN    no  2.000000
# 401                            yes  NaN   3.0  3.0  Sometimes    no  3.000000
# 496                            yes  yes   3.0  3.0        NaN    no  1.152736
# 497                            yes  NaN   3.0  3.0  Sometimes    no  1.115967
# 498                            yes  yes   3.0  3.0        NaN    no  2.704507
# 499                            yes  yes   3.0  3.0  Sometimes    no  2.184707
# 500                            yes  yes   3.0  3.0  Sometimes    no  2.406541
# 501                            yes  yes   3.0  3.0  Sometimes    no  2.984323
# 502                            yes  yes   3.0  3.0  Sometimes    no  2.444125
# 504                            yes  NaN   3.0  3.0  Sometimes    no  2.825629
#
#     SCC       FAF       TUE       CALC                 MTRANS  \
# 200  no  0.000000       NaN  Sometimes                    NaN
# 342  no  2.000000  1.000000  Sometimes  Public_Transportation
# 401  no  0.000000  0.000000         no             Automobile
# 496  no  0.319156  1.000000  Sometimes  Public_Transportation
# 497  no  1.541072  1.000000  Sometimes                    NaN
# 498  no  0.000000  0.294990  Sometimes  Public_Transportation
# 499  no  1.978631  0.838957  Sometimes  Public_Transportation
# 500  no  0.100320  0.479221  Sometimes  Public_Transportation
# 501  no  1.586525  0.625350  Sometimes  Public_Transportation
# 502  no  0.000000  0.265790  Sometimes  Public_Transportation
# 504  no  1.399183  0.928972        NaN                    NaN
#
#            NObeyesdad        BMI
# 200  Obesity_Type_III  41.913215
# 342  Obesity_Type_III  42.730620
# 401  Obesity_Type_III  42.730620
# 496  Obesity_Type_III  42.730620
# 497  Obesity_Type_III  44.715131
# 498  Obesity_Type_III  42.091713
# 499  Obesity_Type_III  44.706120
# 500  Obesity_Type_III  48.572062
# 501  Obesity_Type_III  42.730620
# 502  Obesity_Type_III  41.913063
# 504  Obesity_Type_III  42.730620

# %%
imputed_ObIII
# Out:
#      Gender        Age    Height      Weight family_history_with_overweight  \
# 200  Female  25.029111  1.560000  102.000000                            yes
# 342  Female  18.000000  1.870000  149.424703                            yes
# 401  Female  28.900566  1.618972  112.000000                            yes
# 496  Female  25.196214  1.686306  121.509983                            yes
# 497  Female  24.138999  1.683124  126.673780                            yes
# 498  Female  23.518516  1.622397  110.792630                            yes
# 499  Female  21.853826  1.755643  137.796884                            yes
# 500  Female  21.900120  1.843419  165.057269                            yes
# 501  Female  21.252603  1.764462  133.034410                            yes
# 502  Female  26.000000  1.630927  111.485516                            yes
# 504  Female  21.849705  1.770612  133.963349                            yes
#
#     FAVC  FCVC  NCP SMOKE      CH2O SCC       FAF       TUE        BMI  \
# 200   no   3.0  3.0   yes  1.000000  no  0.000000  0.600000  41.913215
# 342  yes   3.0  3.0    no  2.000000  no  2.000000  1.000000  42.730620
# 401  yes   3.0  3.0    no  3.000000  no  0.000000  0.000000  42.730620
# 496  yes   3.0  3.0    no  1.152736  no  0.319156  1.000000  42.730620
# 497   no   3.0  3.0    no  1.115967  no  1.541072  1.000000  44.715131
# 498  yes   3.0  3.0    no  2.704507  no  0.000000  0.294990  42.091713
# 499  yes   3.0  3.0    no  2.184707  no  1.978631  0.838957  44.706120
# 500  yes   3.0  3.0    no  2.406541  no  0.100320  0.479221  48.572062
# 501  yes   3.0  3.0    no  2.984323  no  1.586525  0.625350  42.730620
# 502  yes   3.0  3.0    no  2.444125  no  0.000000  0.265790  41.913063
# 504   no   3.0  3.0    no  2.825629  no  1.399183  0.928972  42.730620
#
#           CALC       CAEC                 MTRANS        NObeyesdad
# 200  Sometimes  Sometimes              Motorbike  Obesity_Type_III
# 342  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 401         no  Sometimes             Automobile  Obesity_Type_III
# 496  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 497  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 498  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 499  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 500  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 501  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 502  Sometimes  Sometimes  Public_Transportation  Obesity_Type_III
# 504  Sometimes  Sometimes              Motorbike  Obesity_Type_III

# %%
train_set_df["BMI"] = train_set_df["Weight"]/(train_set_df["Height"]**2)
train_set_df.groupby("NObeyesdad")["BMI"].mean()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\2773703445.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train_set_df.groupby("NObeyesdad")["BMI"].mean()
# NObeyesdad
# Insufficient_Weight    17.472559
# Normal_Weight          22.158236
# Overweight_Level_I     26.116853
# Overweight_Level_II    28.190959
# Obesity_Type_I         31.389750
# Obesity_Type_II        36.376624
# Obesity_Type_III       43.414946
# Name: BMI, dtype: float64

# %%
train_set_df.iloc[401]
# Out:
# ID                                             404
# Gender                                      Female
# Age                                            NaN
# Height                                    1.618972
# Weight                                       112.0
# family_history_with_overweight                 yes
# FAVC                                           NaN
# FCVC                                           3.0
# NCP                                            3.0
# CAEC                                     Sometimes
# SMOKE                                           no
# CH2O                                           3.0
# SCC                                             no
# FAF                                            0.0
# TUE                                            0.0
# CALC                                            no
# MTRANS                                  Automobile
# NObeyesdad                        Obesity_Type_III
# BMI                                       42.73062
# Name: 401, dtype: object

# %%
train_set_df.iloc[342]
# Out:
# ID                                                  345
# Gender                                              NaN
# Age                                                18.0
# Height                                             1.87
# Weight                                       149.424703
# family_history_with_overweight                      yes
# FAVC                                                yes
# FCVC                                                3.0
# NCP                                                 3.0
# CAEC                                                NaN
# SMOKE                                                no
# CH2O                                                2.0
# SCC                                                  no
# FAF                                                 2.0
# TUE                                                 1.0
# CALC                                          Sometimes
# MTRANS                            Public_Transportation
# NObeyesdad                             Obesity_Type_III
# BMI                                            42.73062
# Name: 342, dtype: object

# %% [markdown]
# ## **3) Snacking and obesity**
#
# CAEC: Consumption of food between meals
# NCP: Number of daily meals

# %%
new_obesity["CAEC"].value_counts()
# Out:
# CAEC
# Sometimes     829
# Frequently    188
# no             54
# Always         36
# Name: count, dtype: int64

# %%
sns.countplot(x="NObeyesdad", data=new_obesity, hue="CAEC")
plt.xticks(rotation=90)
plt.show()

# %%
fig,(ax1,ax2) = plt.subplots(1,2, figsize = (12,8))
sns.countplot(x="NObeyesdad", data=females, hue="CAEC", ax=ax1)
ax1.set_title("Females")
ax1.tick_params("x", rotation=90)
sns.countplot(x="NObeyesdad", data=males, hue="CAEC", ax=ax2)
ax2.tick_params("x", rotation=90)
ax2.set_title("Males")
plt.show()

# %% [markdown]
# Surpisingly, the females *Insuficient_Weight* are the ones who snack the most frequently while the male *Overweight_Level_I* are the ones who snack the least with the class mainly divided between sometimes and no.

# %%
sns.barplot(x="CAEC", y="FCVC", data=new_obesity, hue="NObeyesdad")
plt.legend(loc="center left", bbox_to_anchor=(1,0.5))
plt.show()

# %% [markdown]
# I don't know if they lied but the female *Obesity_Type_III* apparently only snack sometimes but eat a lot of vegetables.

# %%
new_obesity.groupby("family_history_with_overweight")["NObeyesdad"].value_counts()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\2908978086.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   new_obesity.groupby("family_history_with_overweight")["NObeyesdad"].value_counts()
# family_history_with_overweight  NObeyesdad
# no                              Normal_Weight          156
#                                 Insufficient_Weight    153
#                                 Overweight_Level_I      85
#                                 Overweight_Level_II     24
#                                 Obesity_Type_I          11
#                                 Obesity_Type_II          1
#                                 Obesity_Type_III         0
# yes                             Overweight_Level_I     198
#                                 Overweight_Level_II    164
#                                 Normal_Weight          141
#                                 Insufficient_Weight    115
#                                 Obesity_Type_I          37
#                                 Obesity_Type_II         11
#                                 Obesity_Type_III        11
# Name: count, dtype: int64

# %%
Insuf_Weight = new_obesity[new_obesity["NObeyesdad"] == "Insufficient_Weight"].copy()
sns.countplot(x="CAEC",data=Insuf_Weight, hue="family_history_with_overweight")
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x="CAEC",y="FCVC",data=Insuf_Weight, hue="family_history_with_overweight")
plt.xticks(rotation=45)
plt.show()

# %%
males.groupby("CAEC")["NObeyesdad"].value_counts()
# Out:
# C:\Users\Angelique\AppData\Local\Temp\ipykernel_6076\2005882926.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   males.groupby("CAEC")["NObeyesdad"].value_counts()
# CAEC        NObeyesdad
# Always      Normal_Weight           9
#             Obesity_Type_I          3
#             Overweight_Level_I      2
#             Overweight_Level_II     2
#             Insufficient_Weight     1
#             Obesity_Type_II         0
# Frequently  Normal_Weight          26
#             Overweight_Level_II     7
#             Insufficient_Weight     3
#             Overweight_Level_I      3
#             Obesity_Type_I          1
#             Obesity_Type_II         0
# Sometimes   Overweight_Level_I     93
#             Insufficient_Weight    84
#             Overweight_Level_II    84
#             Normal_Weight          75
#             Obesity_Type_I         20
#             Obesity_Type_II         7
# no          Overweight_Level_I     30
#             Normal_Weight           2
#             Obesity_Type_II         2
#             Overweight_Level_II     1
#             Insufficient_Weight     0
#             Obesity_Type_I          0
# Name: count, dtype: int64

# %%
females.groupby("CAEC", observed=False)["NObeyesdad"].value_counts()
# Out:
# CAEC        NObeyesdad
# Always      Normal_Weight           16
#             Overweight_Level_I       1
#             Obesity_Type_I           1
#             Obesity_Type_II          1
#             Insufficient_Weight      0
#             Overweight_Level_II      0
#             Obesity_Type_III         0
# Frequently  Insufficient_Weight     96
#             Normal_Weight           40
#             Overweight_Level_I       7
#             Overweight_Level_II      3
#             Obesity_Type_I           2
#             Obesity_Type_II          0
#             Obesity_Type_III         0
# Sometimes   Overweight_Level_I     135
#             Normal_Weight          125
#             Overweight_Level_II     91
#             Insufficient_Weight     81
#             Obesity_Type_I          21
#             Obesity_Type_III        11
#             Obesity_Type_II          2
# no          Overweight_Level_I      12
#             Normal_Weight            4
#             Insufficient_Weight      3
#             Overweight_Level_II      0
#             Obesity_Type_I           0
#             Obesity_Type_II          0
#             Obesity_Type_III         0
# Name: count, dtype: int64

# %%
males.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 455 entries, 2 to 1106
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          455 non-null    category
#  1   Age                             455 non-null    float64
#  2   Height                          455 non-null    float64
#  3   Weight                          455 non-null    float64
#  4   family_history_with_overweight  455 non-null    category
#  5   FAVC                            455 non-null    category
#  6   FCVC                            455 non-null    float64
#  7   NCP                             455 non-null    float64
#  8   SMOKE                           455 non-null    category
#  9   CH2O                            455 non-null    float64
#  10  SCC                             455 non-null    category
#  11  FAF                             455 non-null    float64
#  12  TUE                             455 non-null    float64
#  13  BMI                             455 non-null    float64
#  14  CALC                            455 non-null    category
#  15  CAEC                            455 non-null    category
#  16  MTRANS                          455 non-null    category
#  17  NObeyesdad                      455 non-null    category
# dtypes: category(9), float64(9)
# memory usage: 40.9 KB

# %%
sns.violinplot(x="NObeyesdad", y="NCP", data=new_obesity)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Apart from the most severe overweight (Obesity type III), all the classes have a larger group of snackers.
